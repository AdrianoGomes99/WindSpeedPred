# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM,Dropout
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict

# %% [markdown]
# #### Context
# High precision and reliable wind speed forecasting is a challenge for meteorologists. Severe wind due to convective storms, causes considerable damages (large scale forest damage, outage, buildings/houses damage, etc.). Convective events such as thunderstorms, tornadoes as well as large hail, strong winds, are natural hazards that have the potential to disrupt daily life, especially over complex terrain favoring the initiation of convection. Even ordinary convective events produce severe winds which causes fatal and costly damages. Therefore, wind speed prediction is an important task to get advanced severe weather warning. This dataset contains the responses of a weather sensor that collected different weather variables such as temperatures and precipitation.
#
# #### Content
# The dataset contains 6574 instances of daily averaged responses from an array of 5 weather variables sensors embedded in a meteorological station. The device was located on the field in a significantly empty area, at 21M. Data were recorded from January 1961 to December 1978 (17 years). Ground Truth daily averaged precipitations, maximum and minimum temperatures, and grass minimum temperature were provided.
#
# #### Attribute Information
# - DATE (YYYY-MM-DD)
# - WIND: Average wind speed [knots]
# - IND: First indicator value
# - RAIN: Precipitation Amount (mm)
# - IND.1: Second indicator value
# - T.MAX: Maximum Temperature (°C)
# - IND.2: Third indicator value
# - T.MIN: Minimum Temperature (°C)
# - T.MIN.G: 09utc Grass Minimum Temperature (°C)

# %%
data = pd.read_csv("wind_dataset.csv")

# %%
data.head()
# Out:
#          DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0  1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1  1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2  1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3  1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4  1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5

# %%
data.rename(columns={"IND":"IND1", "IND.1":"IND2", "IND.2":"IND3"}, inplace=True)

# %%
data
# Out:
#             DATE   WIND  IND1  RAIN  IND2  T.MAX  IND3  T.MIN  T.MIN.G
# 0     1961-01-01  13.67     0   0.2   0.0    9.5   0.0    3.7     -1.0
# 1     1961-01-02  11.50     0   5.1   0.0    7.2   0.0    4.2      1.1
# 2     1961-01-03  11.25     0   0.4   0.0    5.5   0.0    0.5     -0.5
# 3     1961-01-04   8.63     0   0.2   0.0    5.6   0.0    0.4     -3.2
# 4     1961-01-05  11.92     0  10.4   0.0    7.2   1.0   -1.5     -7.5
# ...          ...    ...   ...   ...   ...    ...   ...    ...      ...
# 6569  1978-12-27  14.46     0  16.8   0.0    9.8   0.0    4.0      0.0
# 6570  1978-12-28  14.33     0  16.0   0.0    9.1   0.0    8.5      8.0
# 6571  1978-12-29  19.17     0  14.7   0.0    5.0   0.0    3.5      3.2
# 6572  1978-12-30  18.08     0   4.9   0.0    2.9   0.0    0.3     -0.5
# 6573  1978-12-31  19.25     0   0.5   0.0    1.2   1.0   -1.5     -3.0
#
# [6574 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     6574 non-null   object
#  1   WIND     6574 non-null   float64
#  2   IND1     6574 non-null   int64
#  3   RAIN     6574 non-null   float64
#  4   IND2     6513 non-null   float64
#  5   T.MAX    5953 non-null   float64
#  6   IND3     6513 non-null   float64
#  7   T.MIN    5900 non-null   float64
#  8   T.MIN.G  6214 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 462.4+ KB

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6569    False
# 6570    False
# 6571    False
# 6572    False
# 6573    False
# Length: 6574, dtype: bool

# %%
data["DATE"] = pd.to_datetime(data["DATE"])

# %%
data = data.set_index("DATE")

# %%
data.head(5)
# Out:
#              WIND  IND1  RAIN  IND2  T.MAX  IND3  T.MIN  T.MIN.G
# DATE
# 1961-01-01  13.67     0   0.2   0.0    9.5   0.0    3.7     -1.0
# 1961-01-02  11.50     0   5.1   0.0    7.2   0.0    4.2      1.1
# 1961-01-03  11.25     0   0.4   0.0    5.5   0.0    0.5     -0.5
# 1961-01-04   8.63     0   0.2   0.0    5.6   0.0    0.4     -3.2
# 1961-01-05  11.92     0  10.4   0.0    7.2   1.0   -1.5     -7.5

# %%
data.count()
# Out:
# WIND       6574
# IND1       6574
# RAIN       6574
# IND2       6513
# T.MAX      5953
# IND3       6513
# T.MIN      5900
# T.MIN.G    6214
# dtype: int64

# %%
sns.heatmap(data.corr(), annot=True, cmap="Blues", fmt=".1f")
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(5, figsize=(10, 10))
sns.boxplot(data["WIND"], ax=axs[0])
sns.boxplot(data["RAIN"], ax=axs[1])
sns.boxplot(data["T.MAX"], ax=axs[2])
sns.boxplot(data["T.MIN"], ax=axs[3])
sns.boxplot(data["T.MIN.G"], ax=axs[4])
fig.tight_layout()
plt.show()
# Out:
# c:\Users\Rodrigo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\Rodrigo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\Rodrigo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\Rodrigo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\Rodrigo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, axs = plt.subplots(3, figsize=(10, 10))
sns.histplot(data["IND1"], ax=axs[0])
sns.histplot(data["IND2"], ax=axs[1])
sns.histplot(data["IND3"], ax=axs[2])
fig.tight_layout()
plt.show()

# %%
values = data.values

groups = [g  for g in range(8)]

i = 1

plt.figure(figsize=(100, 15))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.ylabel(data.columns[group])
    i += 1
plt.show()

# %% [markdown]
# As features IND1, IND2 e IND3 parecem estar correlacionadas com as restantes features. Pelo plot das diferentes features, os valores de IND1, IND2 e IND3 são inteiros e parecem classificar a variação nos valores das features Temperature and IND (quando alguma desta features assume o valor NaN, o indicador correspondente assume o valor 4).
#
# O autor do dataset foi questionado sobre o significado desta variáveis, para melhor entender o dataset, mas não se obteve resposta.

# %%
#dframe = data.drop(["IND1", "IND2", "IND3"], axis=1)
dframe = data.copy()

# %%
dframe.head()
# Out:
#              WIND  IND1  RAIN  IND2  T.MAX  IND3  T.MIN  T.MIN.G
# DATE
# 1961-01-01  13.67     0   0.2   0.0    9.5   0.0    3.7     -1.0
# 1961-01-02  11.50     0   5.1   0.0    7.2   0.0    4.2      1.1
# 1961-01-03  11.25     0   0.4   0.0    5.5   0.0    0.5     -0.5
# 1961-01-04   8.63     0   0.2   0.0    5.6   0.0    0.4     -3.2
# 1961-01-05  11.92     0  10.4   0.0    7.2   1.0   -1.5     -7.5

# %%
values = dframe.values

groups = [g  for g in range(dframe.shape[1])]

i = 1

plt.figure(figsize=(30, 15))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.ylabel(dframe.columns[group])
    i += 1
plt.show()

# %% [markdown]
# ### Deal with missing values

# %%
dframe
# Out:
#              WIND  IND1  RAIN  IND2  T.MAX  IND3  T.MIN  T.MIN.G
# DATE
# 1961-01-01  13.67     0   0.2   0.0    9.5   0.0    3.7     -1.0
# 1961-01-02  11.50     0   5.1   0.0    7.2   0.0    4.2      1.1
# 1961-01-03  11.25     0   0.4   0.0    5.5   0.0    0.5     -0.5
# 1961-01-04   8.63     0   0.2   0.0    5.6   0.0    0.4     -3.2
# 1961-01-05  11.92     0  10.4   0.0    7.2   1.0   -1.5     -7.5
# ...           ...   ...   ...   ...    ...   ...    ...      ...
# 1978-12-27  14.46     0  16.8   0.0    9.8   0.0    4.0      0.0
# 1978-12-28  14.33     0  16.0   0.0    9.1   0.0    8.5      8.0
# 1978-12-29  19.17     0  14.7   0.0    5.0   0.0    3.5      3.2
# 1978-12-30  18.08     0   4.9   0.0    2.9   0.0    0.3     -0.5
# 1978-12-31  19.25     0   0.5   0.0    1.2   1.0   -1.5     -3.0
#
# [6574 rows x 8 columns]

# %%
dframe.notna().value_counts()
# Out:
# WIND  IND1  RAIN  IND2   T.MAX  IND3   T.MIN  T.MIN.G
# True  True  True  True   True   True   True   True       5638
#                          False  True   False  True        543
#                          True   True   True   False       260
#                   False  False  False  False  False        61
#                   True   True   True   False  True         31
#                                               False        24
#                          False  True   False  False        15
#                                        True   True          2
# dtype: int64

# %%
sns.heatmap(dframe.dropna().corr(), annot=True, cmap="Greens", fmt=".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# T.MAX, T.MIN e T.MIN.G são altamente correlacionadas (problema da multicolinariedade? Remover duas das três features?)

# %%
import miceforest as mf

# %%
# Create kernels. 
kernel1 = mf.ImputationKernel(
  data=dframe,
  save_all_iterations=True,
  random_state=1991
)

# Run the MICE algorithm for 3 iterations on each of the datasets
kernel1.mice(3,verbose=True)
# Out:
# Initialized logger with name mice 1-3
# Dataset 0
# 1  | IND2 | IND3 | T.MIN.G | T.MAX | T.MIN
# 2  | IND2 | IND3 | T.MIN.G | T.MAX | T.MIN
# 3  | IND2 | IND3 | T.MIN.G | T.MAX | T.MIN

# %%
dframe = kernel1.complete_data(0)

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6574 entries, 1961-01-01 to 1978-12-31
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   WIND     6574 non-null   float64
#  1   IND1     6574 non-null   int64
#  2   RAIN     6574 non-null   float64
#  3   IND2     6574 non-null   float64
#  4   T.MAX    6574 non-null   float64
#  5   IND3     6574 non-null   float64
#  6   T.MIN    6574 non-null   float64
#  7   T.MIN.G  6574 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 462.2 KB

# %%
values = dframe.values

groups = [g  for g in range(dframe.shape[1])]

i = 1

plt.figure(figsize=(30, 15))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.ylabel(dframe.columns[group])
    i += 1
plt.xlabel("Observation")
plt.show()

# %%
dframe.head()
# Out:
#              WIND  IND1  RAIN  IND2  T.MAX  IND3  T.MIN  T.MIN.G
# DATE
# 1961-01-01  13.67     0   0.2   0.0    9.5   0.0    3.7     -1.0
# 1961-01-02  11.50     0   5.1   0.0    7.2   0.0    4.2      1.1
# 1961-01-03  11.25     0   0.4   0.0    5.5   0.0    0.5     -0.5
# 1961-01-04   8.63     0   0.2   0.0    5.6   0.0    0.4     -3.2
# 1961-01-05  11.92     0  10.4   0.0    7.2   1.0   -1.5     -7.5

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True): 
    """
        data: data matrix
        n_in: number of input lag timesteps (hours)
        n_out: number of output prediction timesteps (hours)
 
    """
        
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)  #transforms data (pure matrix of values) into data structure adding index of rows and columns
    cols, names = list(), list()  #inicialize empty lists 
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
values.shape[0]
# Out:
# 6574

# %%
values.shape[1]
# Out:
# 8

# %%
from pandas import DataFrame, concat

# %%
list(range(53,46,-1))
# Out:
# [53, 52, 51, 50, 49, 48, 47]

# %%
# ensure all data is float
values = values.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(values)
scaled =  scaler.transform(values)  #apply scaler to the values 


# specify the number of lag days. You can change this hyper-parameter
n_days = 7

# call series_to_supervised to frame data as supervised learning
reframed = series_to_supervised(scaled, n_in=n_days, n_out=1, dropnan=True)

print(reframed.head(3))

# we want to predict only the feature pm2.5 =var1(t)
# Take out the columns of var2(t), var3(t),...var8(t). The indexes below are correct if n_hours = 3
reframed.drop(reframed.columns[list(range(55,48,-1))], axis=1, inplace=True)

#Observe the difference before and after the drop step 
print(reframed.head(3))
# Out:
#    var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  var6(t-7)  \
# 7   0.450115        0.0   0.002985        0.0   0.356877        0.0
# 8   0.378663        0.0   0.076119        0.0   0.271375        0.0
# 9   0.370431        0.0   0.005970        0.0   0.208178        0.0
#
#    var7(t-7)  var8(t-7)  var1(t-6)  var2(t-6)  ...  var7(t-1)  var8(t-1)  \
# 7   0.515254   0.443709   0.378663        0.0  ...   0.308475   0.241722
# 8   0.532203   0.513245   0.370431        0.0  ...   0.494915   0.476821
# 9   0.406780   0.460265   0.284162        0.0  ...   0.471186   0.450331
#
#     var1(t)  var2(t)   var3(t)  var4(t)   var5(t)  var6(t)   var7(t)   var8(t)
# 7  0.470530      0.0  0.000000      0.0  0.249071      0.0  0.494915  0.476821
# 8  0.264735      0.0  0.123881      0.0  0.256506      0.0  0.471186  0.450331
# 9  0.376029      0.0  0.000000      0.0  0.245353      0.0  0.491525  0.493377
#
# [3 rows x 64 columns]
#    var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  var6(t-7)  \
# 7   0.450115        0.0   0.002985        0.0   0.356877        0.0
# 8   0.378663        0.0   0.076119        0.0   0.271375        0.0
# 9   0.370431        0.0   0.005970        0.0   0.208178        0.0
#
#    var7(t-7)  var8(t-7)  var1(t-6)  var2(t-6)  ...  var8(t-2)  var1(t-1)  \
# 7   0.515254   0.443709   0.378663        0.0  ...   0.410596   0.301943
# 8   0.532203   0.513245   0.370431        0.0  ...   0.241722   0.470530
# 9   0.406780   0.460265   0.284162        0.0  ...   0.476821   0.264735
#
#     var1(t)  var2(t)   var3(t)  var4(t)   var5(t)  var6(t)   var7(t)   var8(t)
# 7  0.470530      0.0  0.000000      0.0  0.249071      0.0  0.494915  0.476821
# 8  0.264735      0.0  0.123881      0.0  0.256506      0.0  0.471186  0.450331
# 9  0.376029      0.0  0.000000      0.0  0.245353      0.0  0.491525  0.493377
#
# [3 rows x 57 columns]

# %%
values.shape
# Out:
# (6574, 8)

# %%
data.shape[0]
# Out:
# 6574

# %%
data.shape[0]/365
# Out:
# 18.01095890410959

# %%
18/4
# Out:
# 4.5

# %%
int((data.shape[0]-round(int(data.shape[0]/365)/4))/365)
# Out:
# 18

# %%
data.shape[1]
# Out:
# 8

# %%
data.shape[0]*0.75
# Out:
# 4930.5

# %% [markdown]
# ## Split Data
#
# First, data is split into train and test subsets.
#
# Then the train and test sets are split into input and output variables.
#
# Finally, the inputs (X) are reshaped into 3D format expected by LSTMs, namely [samples, timesteps, features].
#
# **Total data**: 6574 samples (18 years x 365 days + 4 days (leap years)), 8 features.
#
# **Train data**: 3D tensor(samples, timesteps, features).
# 4930 samples:  Data until day 1974-07-01 (75%)
#
# **Test data**: 3D tensor (samples, timesteps, features). The rest of 1644 samples.

# %%
dframe[:4930]
# Out:
#              WIND  IND1  RAIN  IND2  T.MAX  IND3  T.MIN  T.MIN.G
# DATE
# 1961-01-01  13.67     0   0.2   0.0    9.5   0.0    3.7     -1.0
# 1961-01-02  11.50     0   5.1   0.0    7.2   0.0    4.2      1.1
# 1961-01-03  11.25     0   0.4   0.0    5.5   0.0    0.5     -0.5
# 1961-01-04   8.63     0   0.2   0.0    5.6   0.0    0.4     -3.2
# 1961-01-05  11.92     0  10.4   0.0    7.2   1.0   -1.5     -7.5
# ...           ...   ...   ...   ...    ...   ...    ...      ...
# 1974-06-27  10.29     0   0.0   0.0   14.9   0.0   11.3      8.9
# 1974-06-28   4.17     0   0.0   0.0   15.6   0.0   10.6      7.0
# 1974-06-29   3.17     0   0.9   0.0   16.8   0.0    8.6      4.2
# 1974-06-30   5.25     0   3.2   0.0   19.4   0.0    8.6      3.6
# 1974-07-01  12.96     0   1.9   0.0   18.9   0.0   10.7      7.4
#
# [4930 rows x 8 columns]

# %%
m_data = values.shape[0]
n_features = values.shape[1]

# %%
# split into train, validation and test sets

# reframed is a structure that has not only values but also heads and row indixes. Extract only the values 
values = reframed.values
n_train_days = int(len(dframe) * 0.6)

#Extract training subset from values 
train = values[:n_train_days,]

#Extract test subset from values
end_val= int(len(dframe) * 0.75)
val = values[n_train_days:end_val,]
test = values[end_val:,]
# split into input and outputs

n_features =  n_features  #number of features 

n_obs = n_days * n_features  # 7*8 =56

# %%
values.shape
# Out:
# (6567, 57)

# %%
n_obs
# Out:
# 56

# %%
train[:,1:].shape
# Out:
# (3944, 56)

# %%
n_days
# Out:
# 7

# %%
n_features
# Out:
# 8

# %%
train_X  = train[:,1:]   # train_X.shape = (4930, 56)
train_y = train[:,0]     # train_y.shape = (4930,)

val_X  =  val[:,:-1]     # test_X.shape = (822, 56)
val_y =  val[:,-1]       # test_y.shape = (822,)

test_X  =  test[:,:-1]   # test_X.shape = (815, 56)
test_y =  test[:,-1]     # test_y.shape = (815,)

# %%
print('train_X.shape={}'.format(train_X.shape))
print('val_X.shape={}'.format(val_X.shape))
print('test_X.shape={}'.format(test_X.shape))
# Out:
# train_X.shape=(3944, 56)
# val_X.shape=(986, 56)
# test_X.shape=(1637, 56)

# %%
print('train_y.shape={}'.format(train_y.shape))
print('val_y.shape={}'.format(val_y.shape))
print('test_y.shape={}'.format(test_y.shape))
# Out:
# train_y.shape=(3944,)
# val_y.shape=(986,)
# test_y.shape=(1637,)

# %%
# reshape input to be 3D [samples, lag_hours, features]
train_X = train_X.reshape(train_X.shape[0], n_days, n_features) # train_X.shape=(4930,7,8)
val_X =  val_X.reshape(val_X.shape[0], n_days, n_features)  # test_X.shape=(822,7,8)
test_X =  test_X.reshape(test_X.shape[0], n_days, n_features)  # test_X.shape=(815,7,8)

# %%
print('train_X.shape={}'.format(train_X.shape))
print('val_X.shape={}'.format(val_X.shape))
print('test_X.shape={}'.format(test_X.shape))
# Out:
# train_X.shape=(3944, 7, 8)
# val_X.shape=(986, 7, 8)
# test_X.shape=(1637, 7, 8)

# %% [markdown]
# ## Define and Fit Model
#
# In this section, we define and fit an LSTM on the multivariate input data.
# We define the LSTM with 100 neurons in the first hidden layer and 1 neuron in the output layer for predicting wind speed.
# We use the Mean Absolute Error (MAE) loss function and the Adam version of stochastic gradient descent.
# The model will be fit for 100 training epochs with batchs of size 40
# At the end of the run both the training and test loss are plotted.

# %% [markdown]
# # 1 Layer

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
n_neurons = 50
# single input_shape = (lag_days, feature)
model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
model.add(Dense(1))  # 1 neuron in the output layer
model.compile(loss='mae', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)
n_epochs=50
batch_size=32
history1 = model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)

#  print history
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss function')
plt.legend(['train', 'validation'])
plt.xlabel('iterations')
plt.show()
# Out:
# Epoch 1/50
# 124/124 - 24s - loss: 0.1585 - val_loss: 0.2441 - 24s/epoch - 190ms/step
# Epoch 2/50
# 124/124 - 1s - loss: 0.1339 - val_loss: 0.2239 - 549ms/epoch - 4ms/step
# Epoch 3/50
# 124/124 - 1s - loss: 0.1311 - val_loss: 0.2229 - 546ms/epoch - 4ms/step
# Epoch 4/50
# 124/124 - 1s - loss: 0.1300 - val_loss: 0.2224 - 538ms/epoch - 4ms/step
# Epoch 5/50
# 124/124 - 1s - loss: 0.1293 - val_loss: 0.2214 - 542ms/epoch - 4ms/step
# Epoch 6/50
# 124/124 - 1s - loss: 0.1288 - val_loss: 0.2204 - 562ms/epoch - 5ms/step
# Epoch 7/50
# 124/124 - 1s - loss: 0.1285 - val_loss: 0.2190 - 535ms/epoch - 4ms/step
# Epoch 8/50
# 124/124 - 1s - loss: 0.1282 - val_loss: 0.2173 - 520ms/epoch - 4ms/step
# Epoch 9/50
# 124/124 - 1s - loss: 0.1280 - val_loss: 0.2156 - 521ms/epoch - 4ms/step
# Epoch 10/50
# 124/124 - 1s - loss: 0.1278 - val_loss: 0.2137 - 539ms/epoch - 4ms/step
# Epoch 11/50
# 124/124 - 1s - loss: 0.1276 - val_loss: 0.2118 - 526ms/epoch - 4ms/step
# Epoch 12/50
# 124/124 - 1s - loss: 0.1275 - val_loss: 0.2100 - 521ms/epoch - 4ms/step
# Epoch 13/50
# 124/124 - 1s - loss: 0.1274 - val_loss: 0.2084 - 532ms/epoch - 4ms/step
# Epoch 14/50
# 124/124 - 1s - loss: 0.1273 - val_loss: 0.2068 - 528ms/epoch - 4ms/step
# Epoch 15/50
# 124/124 - 1s - loss: 0.1272 - val_loss: 0.2054 - 519ms/epoch - 4ms/step
# Epoch 16/50
# 124/124 - 1s - loss: 0.1271 - val_loss: 0.2042 - 515ms/epoch - 4ms/step
# Epoch 17/50
# 124/124 - 1s - loss: 0.1271 - val_loss: 0.2031 - 555ms/epoch - 4ms/step
# Epoch 18/50
# 124/124 - 1s - loss: 0.1270 - val_loss: 0.2020 - 575ms/epoch - 5ms/step
# Epoch 19/50
# 124/124 - 1s - loss: 0.1270 - val_loss: 0.2011 - 514ms/epoch - 4ms/step
# Epoch 20/50
# 124/124 - 1s - loss: 0.1270 - val_loss: 0.2002 - 555ms/epoch - 4ms/step
# Epoch 21/50
# 124/124 - 1s - loss: 0.1269 - val_loss: 0.1993 - 582ms/epoch - 5ms/step
# Epoch 22/50
# 124/124 - 1s - loss: 0.1269 - val_loss: 0.1986 - 585ms/epoch - 5ms/step
# Epoch 23/50
# 124/124 - 1s - loss: 0.1269 - val_loss: 0.1980 - 607ms/epoch - 5ms/step
# Epoch 24/50
# 124/124 - 1s - loss: 0.1268 - val_loss: 0.1974 - 563ms/epoch - 5ms/step
# Epoch 25/50
# 124/124 - 1s - loss: 0.1268 - val_loss: 0.1968 - 569ms/epoch - 5ms/step
# Epoch 26/50
# 124/124 - 1s - loss: 0.1268 - val_loss: 0.1964 - 548ms/epoch - 4ms/step
# Epoch 27/50
# 124/124 - 1s - loss: 0.1268 - val_loss: 0.1958 - 551ms/epoch - 4ms/step
# Epoch 28/50
# 124/124 - 1s - loss: 0.1268 - val_loss: 0.1955 - 556ms/epoch - 4ms/step
# Epoch 29/50
# 124/124 - 1s - loss: 0.1267 - val_loss: 0.1951 - 557ms/epoch - 4ms/step
# Epoch 30/50
# 124/124 - 1s - loss: 0.1267 - val_loss: 0.1947 - 538ms/epoch - 4ms/step
# Epoch 31/50
# 124/124 - 1s - loss: 0.1267 - val_loss: 0.1944 - 536ms/epoch - 4ms/step
# Epoch 32/50
# 124/124 - 1s - loss: 0.1267 - val_loss: 0.1943 - 526ms/epoch - 4ms/step
# Epoch 33/50
# 124/124 - 1s - loss: 0.1267 - val_loss: 0.1940 - 559ms/epoch - 5ms/step
# Epoch 34/50
# 124/124 - 1s - loss: 0.1267 - val_loss: 0.1938 - 535ms/epoch - 4ms/step
# Epoch 35/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1938 - 573ms/epoch - 5ms/step
# Epoch 36/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1937 - 583ms/epoch - 5ms/step
# Epoch 37/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1935 - 533ms/epoch - 4ms/step
# Epoch 38/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1934 - 569ms/epoch - 5ms/step
# Epoch 39/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1934 - 543ms/epoch - 4ms/step
# Epoch 40/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1933 - 520ms/epoch - 4ms/step
# Epoch 41/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1934 - 527ms/epoch - 4ms/step
# Epoch 42/50
# 124/124 - 1s - loss: 0.1266 - val_loss: 0.1934 - 526ms/epoch - 4ms/step
# Epoch 43/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1934 - 549ms/epoch - 4ms/step
# Epoch 44/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1935 - 528ms/epoch - 4ms/step
# Epoch 45/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1936 - 562ms/epoch - 5ms/step
# Epoch 46/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1936 - 522ms/epoch - 4ms/step
# Epoch 47/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1937 - 535ms/epoch - 4ms/step
# Epoch 48/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1939 - 539ms/epoch - 4ms/step
# Epoch 49/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1941 - 521ms/epoch - 4ms/step
# Epoch 50/50
# 124/124 - 1s - loss: 0.1265 - val_loss: 0.1943 - 529ms/epoch - 4ms/step

# %% [markdown]
# # 2 Layers

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
n_neurons = 50
# single input_shape = (lag_days, feature)
model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons))
model.add(Dense(1))  # 1 neuron in the output layer
model.compile(loss='mae', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)
n_epochs=50
batch_size=32
history2 = model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)

#  print history
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Loss function')
plt.legend(['train', 'validation'])
plt.xlabel('iterations')
plt.show()
# Out:
# Epoch 1/50
# 124/124 - 7s - loss: 0.1379 - val_loss: 0.1825 - 7s/epoch - 54ms/step
# Epoch 2/50
# 124/124 - 1s - loss: 0.1206 - val_loss: 0.2077 - 1s/epoch - 8ms/step
# Epoch 3/50
# 124/124 - 1s - loss: 0.1203 - val_loss: 0.2252 - 942ms/epoch - 8ms/step
# Epoch 4/50
# 124/124 - 1s - loss: 0.1184 - val_loss: 0.1916 - 953ms/epoch - 8ms/step
# Epoch 5/50
# 124/124 - 1s - loss: 0.1146 - val_loss: 0.1739 - 930ms/epoch - 7ms/step
# Epoch 6/50
# 124/124 - 1s - loss: 0.1148 - val_loss: 0.2027 - 962ms/epoch - 8ms/step
# Epoch 7/50
# 124/124 - 1s - loss: 0.1131 - val_loss: 0.1752 - 939ms/epoch - 8ms/step
# Epoch 8/50
# 124/124 - 1s - loss: 0.1092 - val_loss: 0.1639 - 921ms/epoch - 7ms/step
# Epoch 9/50
# 124/124 - 1s - loss: 0.1091 - val_loss: 0.1582 - 1s/epoch - 8ms/step
# Epoch 10/50
# 124/124 - 1s - loss: 0.1089 - val_loss: 0.1723 - 924ms/epoch - 7ms/step
# Epoch 11/50
# 124/124 - 1s - loss: 0.1088 - val_loss: 0.1592 - 953ms/epoch - 8ms/step
# Epoch 12/50
# 124/124 - 1s - loss: 0.1076 - val_loss: 0.1594 - 927ms/epoch - 7ms/step
# Epoch 13/50
# 124/124 - 1s - loss: 0.1084 - val_loss: 0.1817 - 946ms/epoch - 8ms/step
# Epoch 14/50
# 124/124 - 1s - loss: 0.1085 - val_loss: 0.1885 - 999ms/epoch - 8ms/step
# Epoch 15/50
# 124/124 - 1s - loss: 0.1074 - val_loss: 0.1682 - 942ms/epoch - 8ms/step
# Epoch 16/50
# 124/124 - 1s - loss: 0.1071 - val_loss: 0.1748 - 979ms/epoch - 8ms/step
# Epoch 17/50
# 124/124 - 1s - loss: 0.1061 - val_loss: 0.1697 - 950ms/epoch - 8ms/step
# Epoch 18/50
# 124/124 - 1s - loss: 0.1068 - val_loss: 0.1666 - 927ms/epoch - 7ms/step
# Epoch 19/50
# 124/124 - 1s - loss: 0.1067 - val_loss: 0.1762 - 917ms/epoch - 7ms/step
# Epoch 20/50
# 124/124 - 1s - loss: 0.1055 - val_loss: 0.1733 - 936ms/epoch - 8ms/step
# Epoch 21/50
# 124/124 - 1s - loss: 0.1064 - val_loss: 0.1763 - 969ms/epoch - 8ms/step
# Epoch 22/50
# 124/124 - 1s - loss: 0.1054 - val_loss: 0.1794 - 922ms/epoch - 7ms/step
# Epoch 23/50
# 124/124 - 1s - loss: 0.1052 - val_loss: 0.1715 - 930ms/epoch - 8ms/step
# Epoch 24/50
# 124/124 - 1s - loss: 0.1047 - val_loss: 0.1830 - 935ms/epoch - 8ms/step
# Epoch 25/50
# 124/124 - 1s - loss: 0.1039 - val_loss: 0.2047 - 963ms/epoch - 8ms/step
# Epoch 26/50
# 124/124 - 1s - loss: 0.1046 - val_loss: 0.1919 - 963ms/epoch - 8ms/step
# Epoch 27/50
# 124/124 - 1s - loss: 0.1050 - val_loss: 0.1987 - 983ms/epoch - 8ms/step
# Epoch 28/50
# 124/124 - 1s - loss: 0.1043 - val_loss: 0.1971 - 1s/epoch - 9ms/step
# Epoch 29/50
# 124/124 - 1s - loss: 0.1038 - val_loss: 0.2004 - 940ms/epoch - 8ms/step
# Epoch 30/50
# 124/124 - 1s - loss: 0.1035 - val_loss: 0.1694 - 951ms/epoch - 8ms/step
# Epoch 31/50
# 124/124 - 1s - loss: 0.1032 - val_loss: 0.1945 - 1s/epoch - 8ms/step
# Epoch 32/50
# 124/124 - 1s - loss: 0.1028 - val_loss: 0.1830 - 1s/epoch - 8ms/step
# Epoch 33/50
# 124/124 - 1s - loss: 0.1033 - val_loss: 0.1957 - 935ms/epoch - 8ms/step
# Epoch 34/50
# 124/124 - 1s - loss: 0.1031 - val_loss: 0.1838 - 929ms/epoch - 7ms/step
# Epoch 35/50
# 124/124 - 1s - loss: 0.1033 - val_loss: 0.1747 - 931ms/epoch - 8ms/step
# Epoch 36/50
# 124/124 - 1s - loss: 0.1022 - val_loss: 0.1741 - 976ms/epoch - 8ms/step
# Epoch 37/50
# 124/124 - 1s - loss: 0.1030 - val_loss: 0.1636 - 909ms/epoch - 7ms/step
# Epoch 38/50
# 124/124 - 1s - loss: 0.1027 - val_loss: 0.1614 - 929ms/epoch - 7ms/step
# Epoch 39/50
# 124/124 - 1s - loss: 0.1019 - val_loss: 0.1694 - 920ms/epoch - 7ms/step
# Epoch 40/50
# 124/124 - 1s - loss: 0.1024 - val_loss: 0.1645 - 1s/epoch - 8ms/step
# Epoch 41/50
# 124/124 - 1s - loss: 0.1025 - val_loss: 0.1658 - 1s/epoch - 8ms/step
# Epoch 42/50
# 124/124 - 1s - loss: 0.1023 - val_loss: 0.1651 - 905ms/epoch - 7ms/step
# Epoch 43/50
# 124/124 - 1s - loss: 0.1023 - val_loss: 0.1530 - 878ms/epoch - 7ms/step
# Epoch 44/50
# 124/124 - 1s - loss: 0.1022 - val_loss: 0.1602 - 894ms/epoch - 7ms/step
# Epoch 45/50
# 124/124 - 1s - loss: 0.1015 - val_loss: 0.1663 - 977ms/epoch - 8ms/step
# Epoch 46/50
# 124/124 - 1s - loss: 0.1018 - val_loss: 0.1805 - 889ms/epoch - 7ms/step
# Epoch 47/50
# 124/124 - 1s - loss: 0.1007 - val_loss: 0.1678 - 916ms/epoch - 7ms/step
# Epoch 48/50
# 124/124 - 1s - loss: 0.1014 - val_loss: 0.1634 - 905ms/epoch - 7ms/step
# Epoch 49/50
# 124/124 - 1s - loss: 0.1010 - val_loss: 0.1734 - 933ms/epoch - 8ms/step
# Epoch 50/50
# 124/124 - 1s - loss: 0.1016 - val_loss: 0.1653 - 938ms/epoch - 8ms/step

# %% [markdown]
# # 3 Layers

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
n_neurons = 50
# single input_shape = (lag_days, feature)
model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons))
model.add(Dense(1))  # 1 neuron in the output layer
model.compile(loss='mse', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)
n_epochs=50
batch_size=32
history3 = model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)

#  print history
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('Loss function')
plt.legend(['train', 'validation'])
plt.xlabel('iterations')
plt.show()
# Out:
# Epoch 1/50
# 124/124 - 9s - loss: 0.0355 - val_loss: 0.0740 - 9s/epoch - 75ms/step
# Epoch 2/50
# 124/124 - 1s - loss: 0.0231 - val_loss: 0.0470 - 1s/epoch - 11ms/step
# Epoch 3/50
# 124/124 - 1s - loss: 0.0220 - val_loss: 0.0476 - 1s/epoch - 11ms/step
# Epoch 4/50
# 124/124 - 1s - loss: 0.0219 - val_loss: 0.0498 - 1s/epoch - 11ms/step
# Epoch 5/50
# 124/124 - 1s - loss: 0.0214 - val_loss: 0.0464 - 1s/epoch - 11ms/step
# Epoch 6/50
# 124/124 - 1s - loss: 0.0211 - val_loss: 0.0394 - 1s/epoch - 11ms/step
# Epoch 7/50
# 124/124 - 1s - loss: 0.0207 - val_loss: 0.0381 - 1s/epoch - 11ms/step
# Epoch 8/50
# 124/124 - 1s - loss: 0.0203 - val_loss: 0.0379 - 1s/epoch - 11ms/step
# Epoch 9/50
# 124/124 - 1s - loss: 0.0202 - val_loss: 0.0399 - 1s/epoch - 11ms/step
# Epoch 10/50
# 124/124 - 1s - loss: 0.0201 - val_loss: 0.0427 - 1s/epoch - 11ms/step
# Epoch 11/50
# 124/124 - 1s - loss: 0.0197 - val_loss: 0.0404 - 1s/epoch - 11ms/step
# Epoch 12/50
# 124/124 - 1s - loss: 0.0192 - val_loss: 0.0431 - 1s/epoch - 11ms/step
# Epoch 13/50
# 124/124 - 1s - loss: 0.0190 - val_loss: 0.0468 - 1s/epoch - 11ms/step
# Epoch 14/50
# 124/124 - 1s - loss: 0.0187 - val_loss: 0.0440 - 1s/epoch - 11ms/step
# Epoch 15/50
# 124/124 - 1s - loss: 0.0187 - val_loss: 0.0463 - 1s/epoch - 11ms/step
# Epoch 16/50
# 124/124 - 1s - loss: 0.0185 - val_loss: 0.0402 - 1s/epoch - 11ms/step
# Epoch 17/50
# 124/124 - 1s - loss: 0.0183 - val_loss: 0.0367 - 1s/epoch - 11ms/step
# Epoch 18/50
# 124/124 - 1s - loss: 0.0182 - val_loss: 0.0420 - 1s/epoch - 11ms/step
# Epoch 19/50
# 124/124 - 1s - loss: 0.0182 - val_loss: 0.0416 - 1s/epoch - 12ms/step
# Epoch 20/50
# 124/124 - 1s - loss: 0.0181 - val_loss: 0.0387 - 1s/epoch - 12ms/step
# Epoch 21/50
# 124/124 - 1s - loss: 0.0180 - val_loss: 0.0416 - 1s/epoch - 12ms/step
# Epoch 22/50
# 124/124 - 1s - loss: 0.0180 - val_loss: 0.0359 - 1s/epoch - 11ms/step
# Epoch 23/50
# 124/124 - 1s - loss: 0.0179 - val_loss: 0.0402 - 1s/epoch - 11ms/step
# Epoch 24/50
# 124/124 - 1s - loss: 0.0181 - val_loss: 0.0410 - 1s/epoch - 11ms/step
# Epoch 25/50
# 124/124 - 1s - loss: 0.0178 - val_loss: 0.0399 - 1s/epoch - 11ms/step
# Epoch 26/50
# 124/124 - 1s - loss: 0.0177 - val_loss: 0.0402 - 1s/epoch - 11ms/step
# Epoch 27/50
# 124/124 - 1s - loss: 0.0177 - val_loss: 0.0376 - 1s/epoch - 11ms/step
# Epoch 28/50
# 124/124 - 1s - loss: 0.0176 - val_loss: 0.0368 - 1s/epoch - 11ms/step
# Epoch 29/50
# 124/124 - 1s - loss: 0.0177 - val_loss: 0.0367 - 1s/epoch - 11ms/step
# Epoch 30/50
# 124/124 - 1s - loss: 0.0176 - val_loss: 0.0378 - 1s/epoch - 11ms/step
# Epoch 31/50
# 124/124 - 1s - loss: 0.0175 - val_loss: 0.0369 - 1s/epoch - 11ms/step
# Epoch 32/50
# 124/124 - 1s - loss: 0.0173 - val_loss: 0.0417 - 1s/epoch - 11ms/step
# Epoch 33/50
# 124/124 - 1s - loss: 0.0174 - val_loss: 0.0402 - 1s/epoch - 11ms/step
# Epoch 34/50
# 124/124 - 1s - loss: 0.0173 - val_loss: 0.0356 - 1s/epoch - 11ms/step
# Epoch 35/50
# 124/124 - 1s - loss: 0.0173 - val_loss: 0.0375 - 1s/epoch - 11ms/step
# Epoch 36/50
# 124/124 - 1s - loss: 0.0173 - val_loss: 0.0418 - 1s/epoch - 11ms/step
# Epoch 37/50
# 124/124 - 1s - loss: 0.0171 - val_loss: 0.0417 - 1s/epoch - 11ms/step
# Epoch 38/50
# 124/124 - 1s - loss: 0.0171 - val_loss: 0.0403 - 1s/epoch - 11ms/step
# Epoch 39/50
# 124/124 - 1s - loss: 0.0170 - val_loss: 0.0414 - 1s/epoch - 11ms/step
# Epoch 40/50
# 124/124 - 1s - loss: 0.0170 - val_loss: 0.0430 - 1s/epoch - 11ms/step
# Epoch 41/50
# 124/124 - 1s - loss: 0.0169 - val_loss: 0.0426 - 1s/epoch - 12ms/step
# Epoch 42/50
# 124/124 - 1s - loss: 0.0169 - val_loss: 0.0459 - 1s/epoch - 11ms/step
# Epoch 43/50
# 124/124 - 1s - loss: 0.0169 - val_loss: 0.0465 - 1s/epoch - 11ms/step
# Epoch 44/50
# 124/124 - 1s - loss: 0.0168 - val_loss: 0.0414 - 1s/epoch - 11ms/step
# Epoch 45/50
# 124/124 - 1s - loss: 0.0168 - val_loss: 0.0468 - 1s/epoch - 11ms/step
# Epoch 46/50
# 124/124 - 1s - loss: 0.0168 - val_loss: 0.0477 - 1s/epoch - 11ms/step
# Epoch 47/50
# 124/124 - 1s - loss: 0.0168 - val_loss: 0.0443 - 1s/epoch - 11ms/step
# Epoch 48/50
# 124/124 - 1s - loss: 0.0166 - val_loss: 0.0479 - 1s/epoch - 11ms/step
# Epoch 49/50
# 124/124 - 1s - loss: 0.0168 - val_loss: 0.0409 - 1s/epoch - 11ms/step
# Epoch 50/50
# 124/124 - 1s - loss: 0.0167 - val_loss: 0.0471 - 1s/epoch - 11ms/step

# %% [markdown]
# ## 4 Layers

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
n_neurons = 50
# single input_shape = (lag_days, feature)
model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons))
model.add(Dense(1))  # 1 neuron in the output layer
model.compile(loss='mae', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)
n_epochs=50
batch_size=32
history4 = model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)

#  print history
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('Loss function')
plt.legend(['train', 'validation'])
plt.xlabel('iterations')
plt.show()
# Out:
# Epoch 1/50
# 124/124 - 12s - loss: 0.1537 - val_loss: 0.2992 - 12s/epoch - 97ms/step
# Epoch 2/50
# 124/124 - 2s - loss: 0.1254 - val_loss: 0.2420 - 2s/epoch - 13ms/step
# Epoch 3/50
# 124/124 - 2s - loss: 0.1208 - val_loss: 0.2210 - 2s/epoch - 14ms/step
# Epoch 4/50
# 124/124 - 2s - loss: 0.1168 - val_loss: 0.2205 - 2s/epoch - 14ms/step
# Epoch 5/50
# 124/124 - 2s - loss: 0.1157 - val_loss: 0.1981 - 2s/epoch - 14ms/step
# Epoch 6/50
# 124/124 - 2s - loss: 0.1143 - val_loss: 0.1997 - 2s/epoch - 14ms/step
# Epoch 7/50
# 124/124 - 2s - loss: 0.1128 - val_loss: 0.2039 - 2s/epoch - 14ms/step
# Epoch 8/50
# 124/124 - 2s - loss: 0.1124 - val_loss: 0.2095 - 2s/epoch - 14ms/step
# Epoch 9/50
# 124/124 - 2s - loss: 0.1122 - val_loss: 0.1774 - 2s/epoch - 14ms/step
# Epoch 10/50
# 124/124 - 2s - loss: 0.1117 - val_loss: 0.2012 - 2s/epoch - 14ms/step
# Epoch 11/50
# 124/124 - 2s - loss: 0.1112 - val_loss: 0.2035 - 2s/epoch - 14ms/step
# Epoch 12/50
# 124/124 - 2s - loss: 0.1108 - val_loss: 0.1974 - 2s/epoch - 14ms/step
# Epoch 13/50
# 124/124 - 2s - loss: 0.1108 - val_loss: 0.1853 - 2s/epoch - 14ms/step
# Epoch 14/50
# 124/124 - 2s - loss: 0.1100 - val_loss: 0.1770 - 2s/epoch - 14ms/step
# Epoch 15/50
# 124/124 - 2s - loss: 0.1097 - val_loss: 0.1823 - 2s/epoch - 14ms/step
# Epoch 16/50
# 124/124 - 2s - loss: 0.1097 - val_loss: 0.1767 - 2s/epoch - 14ms/step
# Epoch 17/50
# 124/124 - 2s - loss: 0.1097 - val_loss: 0.1700 - 2s/epoch - 14ms/step
# Epoch 18/50
# 124/124 - 2s - loss: 0.1087 - val_loss: 0.1701 - 2s/epoch - 14ms/step
# Epoch 19/50
# 124/124 - 2s - loss: 0.1086 - val_loss: 0.1747 - 2s/epoch - 14ms/step
# Epoch 20/50
# 124/124 - 2s - loss: 0.1088 - val_loss: 0.1752 - 2s/epoch - 14ms/step
# Epoch 21/50
# 124/124 - 2s - loss: 0.1082 - val_loss: 0.1658 - 2s/epoch - 14ms/step
# Epoch 22/50
# 124/124 - 2s - loss: 0.1076 - val_loss: 0.1648 - 2s/epoch - 14ms/step
# Epoch 23/50
# 124/124 - 2s - loss: 0.1075 - val_loss: 0.1590 - 2s/epoch - 14ms/step
# Epoch 24/50
# 124/124 - 2s - loss: 0.1078 - val_loss: 0.1597 - 2s/epoch - 14ms/step
# Epoch 25/50
# 124/124 - 2s - loss: 0.1074 - val_loss: 0.1477 - 2s/epoch - 14ms/step
# Epoch 26/50
# 124/124 - 2s - loss: 0.1066 - val_loss: 0.1557 - 2s/epoch - 14ms/step
# Epoch 27/50
# 124/124 - 2s - loss: 0.1071 - val_loss: 0.1575 - 2s/epoch - 13ms/step
# Epoch 28/50
# 124/124 - 2s - loss: 0.1074 - val_loss: 0.1504 - 2s/epoch - 14ms/step
# Epoch 29/50
# 124/124 - 2s - loss: 0.1062 - val_loss: 0.1592 - 2s/epoch - 14ms/step
# Epoch 30/50
# 124/124 - 2s - loss: 0.1065 - val_loss: 0.1502 - 2s/epoch - 14ms/step
# Epoch 31/50
# 124/124 - 2s - loss: 0.1061 - val_loss: 0.1446 - 2s/epoch - 14ms/step
# Epoch 32/50
# 124/124 - 2s - loss: 0.1057 - val_loss: 0.1487 - 2s/epoch - 14ms/step
# Epoch 33/50
# 124/124 - 2s - loss: 0.1056 - val_loss: 0.1409 - 2s/epoch - 14ms/step
# Epoch 34/50
# 124/124 - 2s - loss: 0.1045 - val_loss: 0.1467 - 2s/epoch - 15ms/step
# Epoch 35/50
# 124/124 - 2s - loss: 0.1050 - val_loss: 0.1523 - 2s/epoch - 14ms/step
# Epoch 36/50
# 124/124 - 2s - loss: 0.1047 - val_loss: 0.1446 - 2s/epoch - 16ms/step
# Epoch 37/50
# 124/124 - 2s - loss: 0.1049 - val_loss: 0.1481 - 2s/epoch - 15ms/step
# Epoch 38/50
# 124/124 - 2s - loss: 0.1040 - val_loss: 0.1420 - 2s/epoch - 14ms/step
# Epoch 39/50
# 124/124 - 2s - loss: 0.1035 - val_loss: 0.1378 - 2s/epoch - 14ms/step
# Epoch 40/50
# 124/124 - 2s - loss: 0.1043 - val_loss: 0.1459 - 2s/epoch - 14ms/step
# Epoch 41/50
# 124/124 - 2s - loss: 0.1037 - val_loss: 0.1411 - 2s/epoch - 14ms/step
# Epoch 42/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1394 - 2s/epoch - 14ms/step
# Epoch 43/50
# 124/124 - 2s - loss: 0.1034 - val_loss: 0.1430 - 2s/epoch - 14ms/step
# Epoch 44/50
# 124/124 - 2s - loss: 0.1035 - val_loss: 0.1435 - 2s/epoch - 14ms/step
# Epoch 45/50
# 124/124 - 2s - loss: 0.1037 - val_loss: 0.1414 - 2s/epoch - 14ms/step
# Epoch 46/50
# 124/124 - 2s - loss: 0.1042 - val_loss: 0.1421 - 2s/epoch - 14ms/step
# Epoch 47/50
# 124/124 - 2s - loss: 0.1032 - val_loss: 0.1453 - 2s/epoch - 14ms/step
# Epoch 48/50
# 124/124 - 2s - loss: 0.1024 - val_loss: 0.1439 - 2s/epoch - 13ms/step
# Epoch 49/50
# 124/124 - 2s - loss: 0.1028 - val_loss: 0.1396 - 2s/epoch - 14ms/step
# Epoch 50/50
# 124/124 - 2s - loss: 0.1028 - val_loss: 0.1400 - 2s/epoch - 14ms/step

# %%
plt.plot(history1.history["loss"], label="Loss 1 Layer")
plt.plot(history1.history["val_loss"], label="Val_Loss 1 Layer")
plt.plot(history2.history["loss"], label="Loss 2 Layer")
plt.plot(history2.history["val_loss"], label="Val_Loss 2 Layer")
plt.plot(history3.history["loss"], label="Loss 3 Layer")
plt.plot(history3.history["val_loss"], label="Val_Loss 3 Layer")
plt.plot(history4.history["loss"], label="Loss 4 Layer")
plt.plot(history4.history["val_loss"], label="Val_Loss 4 Layer")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.title("Loss and Validation Loss")
plt.legend(fontsize=6)

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
n_neurons = 50
# single input_shape = (lag_days, feature)
model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons))
model.add(Dense(1))  # 1 neuron in the output layer
model.compile(loss='mae', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)
n_epochs=50
batch_size=32
history = model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)

#  print history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss function')
plt.legend(['train', 'validation'])
plt.xlabel('iterations')
plt.show()
# Out:
# Epoch 1/50
# 124/124 - 15s - loss: 0.1516 - val_loss: 0.3249 - 15s/epoch - 120ms/step
# Epoch 2/50
# 124/124 - 2s - loss: 0.1259 - val_loss: 0.2685 - 2s/epoch - 16ms/step
# Epoch 3/50
# 124/124 - 2s - loss: 0.1190 - val_loss: 0.2300 - 2s/epoch - 16ms/step
# Epoch 4/50
# 124/124 - 2s - loss: 0.1157 - val_loss: 0.2155 - 2s/epoch - 16ms/step
# Epoch 5/50
# 124/124 - 2s - loss: 0.1141 - val_loss: 0.2063 - 2s/epoch - 17ms/step
# Epoch 6/50
# 124/124 - 2s - loss: 0.1139 - val_loss: 0.2065 - 2s/epoch - 17ms/step
# Epoch 7/50
# 124/124 - 2s - loss: 0.1129 - val_loss: 0.2116 - 2s/epoch - 17ms/step
# Epoch 8/50
# 124/124 - 2s - loss: 0.1120 - val_loss: 0.2004 - 2s/epoch - 17ms/step
# Epoch 9/50
# 124/124 - 2s - loss: 0.1118 - val_loss: 0.2219 - 2s/epoch - 17ms/step
# Epoch 10/50
# 124/124 - 2s - loss: 0.1116 - val_loss: 0.2101 - 2s/epoch - 17ms/step
# Epoch 11/50
# 124/124 - 2s - loss: 0.1109 - val_loss: 0.2019 - 2s/epoch - 17ms/step
# Epoch 12/50
# 124/124 - 2s - loss: 0.1106 - val_loss: 0.2020 - 2s/epoch - 17ms/step
# Epoch 13/50
# 124/124 - 2s - loss: 0.1099 - val_loss: 0.1946 - 2s/epoch - 17ms/step
# Epoch 14/50
# 124/124 - 2s - loss: 0.1096 - val_loss: 0.2069 - 2s/epoch - 18ms/step
# Epoch 15/50
# 124/124 - 2s - loss: 0.1096 - val_loss: 0.1908 - 2s/epoch - 17ms/step
# Epoch 16/50
# 124/124 - 2s - loss: 0.1092 - val_loss: 0.1841 - 2s/epoch - 17ms/step
# Epoch 17/50
# 124/124 - 2s - loss: 0.1093 - val_loss: 0.1907 - 2s/epoch - 19ms/step
# Epoch 18/50
# 124/124 - 2s - loss: 0.1095 - val_loss: 0.1902 - 2s/epoch - 17ms/step
# Epoch 19/50
# 124/124 - 2s - loss: 0.1084 - val_loss: 0.1875 - 2s/epoch - 17ms/step
# Epoch 20/50
# 124/124 - 2s - loss: 0.1084 - val_loss: 0.1928 - 2s/epoch - 17ms/step
# Epoch 21/50
# 124/124 - 2s - loss: 0.1081 - val_loss: 0.1683 - 2s/epoch - 17ms/step
# Epoch 22/50
# 124/124 - 2s - loss: 0.1084 - val_loss: 0.1743 - 2s/epoch - 17ms/step
# Epoch 23/50
# 124/124 - 2s - loss: 0.1080 - val_loss: 0.1616 - 2s/epoch - 17ms/step
# Epoch 24/50
# 124/124 - 2s - loss: 0.1078 - val_loss: 0.1715 - 2s/epoch - 17ms/step
# Epoch 25/50
# 124/124 - 2s - loss: 0.1078 - val_loss: 0.1775 - 2s/epoch - 17ms/step
# Epoch 26/50
# 124/124 - 2s - loss: 0.1079 - val_loss: 0.1645 - 2s/epoch - 16ms/step
# Epoch 27/50
# 124/124 - 2s - loss: 0.1074 - val_loss: 0.1645 - 2s/epoch - 17ms/step
# Epoch 28/50
# 124/124 - 2s - loss: 0.1067 - val_loss: 0.1674 - 2s/epoch - 18ms/step
# Epoch 29/50
# 124/124 - 2s - loss: 0.1078 - val_loss: 0.1651 - 2s/epoch - 17ms/step
# Epoch 30/50
# 124/124 - 2s - loss: 0.1079 - val_loss: 0.1657 - 2s/epoch - 16ms/step
# Epoch 31/50
# 124/124 - 2s - loss: 0.1074 - val_loss: 0.1601 - 2s/epoch - 16ms/step
# Epoch 32/50
# 124/124 - 2s - loss: 0.1074 - val_loss: 0.1613 - 2s/epoch - 17ms/step
# Epoch 33/50
# 124/124 - 2s - loss: 0.1070 - val_loss: 0.1643 - 2s/epoch - 18ms/step
# Epoch 34/50
# 124/124 - 2s - loss: 0.1068 - val_loss: 0.1653 - 2s/epoch - 17ms/step
# Epoch 35/50
# 124/124 - 2s - loss: 0.1067 - val_loss: 0.1627 - 2s/epoch - 18ms/step
# Epoch 36/50
# 124/124 - 2s - loss: 0.1066 - val_loss: 0.1594 - 2s/epoch - 17ms/step
# Epoch 37/50
# 124/124 - 2s - loss: 0.1060 - val_loss: 0.1627 - 2s/epoch - 16ms/step
# Epoch 38/50
# 124/124 - 2s - loss: 0.1063 - val_loss: 0.1585 - 2s/epoch - 16ms/step
# Epoch 39/50
# 124/124 - 2s - loss: 0.1061 - val_loss: 0.1587 - 2s/epoch - 16ms/step
# Epoch 40/50
# 124/124 - 2s - loss: 0.1059 - val_loss: 0.1498 - 2s/epoch - 17ms/step
# Epoch 41/50
# 124/124 - 2s - loss: 0.1063 - val_loss: 0.1616 - 2s/epoch - 17ms/step
# Epoch 42/50
# 124/124 - 2s - loss: 0.1061 - val_loss: 0.1581 - 2s/epoch - 16ms/step
# Epoch 43/50
# 124/124 - 2s - loss: 0.1057 - val_loss: 0.1609 - 2s/epoch - 16ms/step
# Epoch 44/50
# 124/124 - 2s - loss: 0.1059 - val_loss: 0.1606 - 2s/epoch - 16ms/step
# Epoch 45/50
# 124/124 - 2s - loss: 0.1062 - val_loss: 0.1617 - 2s/epoch - 16ms/step
# Epoch 46/50
# 124/124 - 2s - loss: 0.1051 - val_loss: 0.1510 - 2s/epoch - 16ms/step
# Epoch 47/50
# 124/124 - 2s - loss: 0.1051 - val_loss: 0.1570 - 2s/epoch - 16ms/step
# Epoch 48/50
# 124/124 - 2s - loss: 0.1051 - val_loss: 0.1586 - 2s/epoch - 16ms/step
# Epoch 49/50
# 124/124 - 2s - loss: 0.1044 - val_loss: 0.1569 - 2s/epoch - 16ms/step
# Epoch 50/50
# 124/124 - 2s - loss: 0.1049 - val_loss: 0.1543 - 2s/epoch - 16ms/step

# %% [markdown]
# ## 4 LSTM layers + 2 Dense

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
n_neurons = 50
# single input_shape = (lag_days, feature)
model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(n_neurons))
model.add(Dropout(0.2))
model.add(Dense(15, activation="relu"))
model.add(Dense(1,activation="sigmoid"))  # 1 neuron in the output layer
model.compile(loss='mae', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)
n_epochs=50
batch_size=32
history = model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)

#  print history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss function')
plt.legend(['train', 'validation'])
plt.xlabel('iterations')
plt.show()
# Out:
# Epoch 1/50
# 124/124 - 12s - loss: 0.1424 - val_loss: 0.2735 - 12s/epoch - 98ms/step
# Epoch 2/50
# 124/124 - 2s - loss: 0.1280 - val_loss: 0.1743 - 2s/epoch - 13ms/step
# Epoch 3/50
# 124/124 - 2s - loss: 0.1188 - val_loss: 0.1787 - 2s/epoch - 13ms/step
# Epoch 4/50
# 124/124 - 2s - loss: 0.1144 - val_loss: 0.1857 - 2s/epoch - 13ms/step
# Epoch 5/50
# 124/124 - 2s - loss: 0.1120 - val_loss: 0.1809 - 2s/epoch - 13ms/step
# Epoch 6/50
# 124/124 - 2s - loss: 0.1117 - val_loss: 0.2016 - 2s/epoch - 13ms/step
# Epoch 7/50
# 124/124 - 2s - loss: 0.1114 - val_loss: 0.1980 - 2s/epoch - 13ms/step
# Epoch 8/50
# 124/124 - 2s - loss: 0.1099 - val_loss: 0.1936 - 2s/epoch - 13ms/step
# Epoch 9/50
# 124/124 - 2s - loss: 0.1097 - val_loss: 0.1842 - 2s/epoch - 13ms/step
# Epoch 10/50
# 124/124 - 2s - loss: 0.1093 - val_loss: 0.1681 - 2s/epoch - 14ms/step
# Epoch 11/50
# 124/124 - 2s - loss: 0.1090 - val_loss: 0.1734 - 2s/epoch - 13ms/step
# Epoch 12/50
# 124/124 - 2s - loss: 0.1082 - val_loss: 0.1807 - 2s/epoch - 13ms/step
# Epoch 13/50
# 124/124 - 2s - loss: 0.1084 - val_loss: 0.1753 - 2s/epoch - 13ms/step
# Epoch 14/50
# 124/124 - 2s - loss: 0.1089 - val_loss: 0.1727 - 2s/epoch - 13ms/step
# Epoch 15/50
# 124/124 - 2s - loss: 0.1085 - val_loss: 0.1611 - 2s/epoch - 13ms/step
# Epoch 16/50
# 124/124 - 2s - loss: 0.1081 - val_loss: 0.1627 - 2s/epoch - 12ms/step
# Epoch 17/50
# 124/124 - 2s - loss: 0.1087 - val_loss: 0.1724 - 2s/epoch - 12ms/step
# Epoch 18/50
# 124/124 - 2s - loss: 0.1075 - val_loss: 0.1704 - 2s/epoch - 13ms/step
# Epoch 19/50
# 124/124 - 2s - loss: 0.1082 - val_loss: 0.1673 - 2s/epoch - 13ms/step
# Epoch 20/50
# 124/124 - 2s - loss: 0.1079 - val_loss: 0.1576 - 2s/epoch - 12ms/step
# Epoch 21/50
# 124/124 - 2s - loss: 0.1075 - val_loss: 0.1585 - 2s/epoch - 13ms/step
# Epoch 22/50
# 124/124 - 2s - loss: 0.1066 - val_loss: 0.1572 - 2s/epoch - 13ms/step
# Epoch 23/50
# 124/124 - 2s - loss: 0.1058 - val_loss: 0.1576 - 2s/epoch - 12ms/step
# Epoch 24/50
# 124/124 - 2s - loss: 0.1065 - val_loss: 0.1639 - 2s/epoch - 13ms/step
# Epoch 25/50
# 124/124 - 2s - loss: 0.1086 - val_loss: 0.1466 - 2s/epoch - 12ms/step
# Epoch 26/50
# 124/124 - 2s - loss: 0.1059 - val_loss: 0.1556 - 2s/epoch - 13ms/step
# Epoch 27/50
# 124/124 - 2s - loss: 0.1056 - val_loss: 0.1567 - 2s/epoch - 13ms/step
# Epoch 28/50
# 124/124 - 2s - loss: 0.1057 - val_loss: 0.1503 - 2s/epoch - 13ms/step
# Epoch 29/50
# 124/124 - 2s - loss: 0.1054 - val_loss: 0.1472 - 2s/epoch - 13ms/step
# Epoch 30/50
# 124/124 - 2s - loss: 0.1046 - val_loss: 0.1497 - 2s/epoch - 12ms/step
# Epoch 31/50
# 124/124 - 2s - loss: 0.1050 - val_loss: 0.1401 - 2s/epoch - 12ms/step
# Epoch 32/50
# 124/124 - 2s - loss: 0.1040 - val_loss: 0.1421 - 2s/epoch - 13ms/step
# Epoch 33/50
# 124/124 - 2s - loss: 0.1052 - val_loss: 0.1395 - 2s/epoch - 12ms/step
# Epoch 34/50
# 124/124 - 2s - loss: 0.1044 - val_loss: 0.1379 - 2s/epoch - 13ms/step
# Epoch 35/50
# 124/124 - 2s - loss: 0.1040 - val_loss: 0.1352 - 2s/epoch - 13ms/step
# Epoch 36/50
# 124/124 - 2s - loss: 0.1029 - val_loss: 0.1361 - 2s/epoch - 12ms/step
# Epoch 37/50
# 124/124 - 1s - loss: 0.1042 - val_loss: 0.1360 - 1s/epoch - 12ms/step
# Epoch 38/50
# 124/124 - 1s - loss: 0.1026 - val_loss: 0.1348 - 1s/epoch - 12ms/step
# Epoch 39/50
# 124/124 - 2s - loss: 0.1036 - val_loss: 0.1340 - 2s/epoch - 12ms/step
# Epoch 40/50
# 124/124 - 2s - loss: 0.1035 - val_loss: 0.1348 - 2s/epoch - 12ms/step
# Epoch 41/50
# 124/124 - 2s - loss: 0.1032 - val_loss: 0.1340 - 2s/epoch - 12ms/step
# Epoch 42/50
# 124/124 - 2s - loss: 0.1027 - val_loss: 0.1361 - 2s/epoch - 12ms/step
# Epoch 43/50
# 124/124 - 2s - loss: 0.1023 - val_loss: 0.1360 - 2s/epoch - 12ms/step
# Epoch 44/50
# 124/124 - 2s - loss: 0.1024 - val_loss: 0.1343 - 2s/epoch - 13ms/step
# Epoch 45/50
# 124/124 - 2s - loss: 0.1030 - val_loss: 0.1355 - 2s/epoch - 13ms/step
# Epoch 46/50
# 124/124 - 2s - loss: 0.1018 - val_loss: 0.1341 - 2s/epoch - 13ms/step
# Epoch 47/50
# 124/124 - 2s - loss: 0.1018 - val_loss: 0.1349 - 2s/epoch - 13ms/step
# Epoch 48/50
# 124/124 - 2s - loss: 0.1019 - val_loss: 0.1342 - 2s/epoch - 12ms/step
# Epoch 49/50
# 124/124 - 2s - loss: 0.1014 - val_loss: 0.1336 - 2s/epoch - 12ms/step
# Epoch 50/50
# 124/124 - 2s - loss: 0.1010 - val_loss: 0.1374 - 2s/epoch - 13ms/step

# %% [markdown]
# ### Best option (1 LSTM layer + 2 Dense)

# %%
# Sequential model is appropriate to design LSTM RNN
model = Sequential()
# train_X : 3D tensor (samples, lag_hours, feature)
n_neurons = 10
# single input_shape = (lag_days, feature)
model.add(LSTM(n_neurons, input_shape=(n_days, n_features)))
model.add(Dense(15, activation="relu"))
model.add(Dense(1, activation="sigmoid"))  # 1 neuron in the output layer
model.compile(loss='mse', optimizer='adam')

# fit network
#verbose=0 will show nothing (silent)
#verbose=1 will show an animated progress bar
#verbose=2 will show the training progress for each epoch (shows loss and val_loss)
n_epochs=100
batch_size=24
history = model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)

#  print history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss function')
plt.legend(['train', 'validation'])
plt.xlabel('iterations')
plt.show()
# Out:
# Epoch 1/100
# 165/165 - 4s - loss: 0.0304 - val_loss: 0.0815 - 4s/epoch - 24ms/step
# Epoch 2/100
# 165/165 - 1s - loss: 0.0256 - val_loss: 0.0609 - 501ms/epoch - 3ms/step
# Epoch 3/100
# 165/165 - 1s - loss: 0.0242 - val_loss: 0.0523 - 516ms/epoch - 3ms/step
# Epoch 4/100
# 165/165 - 1s - loss: 0.0230 - val_loss: 0.0541 - 507ms/epoch - 3ms/step
# Epoch 5/100
# 165/165 - 1s - loss: 0.0220 - val_loss: 0.0553 - 509ms/epoch - 3ms/step
# Epoch 6/100
# 165/165 - 1s - loss: 0.0211 - val_loss: 0.0561 - 502ms/epoch - 3ms/step
# Epoch 7/100
# 165/165 - 1s - loss: 0.0205 - val_loss: 0.0564 - 505ms/epoch - 3ms/step
# Epoch 8/100
# 165/165 - 1s - loss: 0.0200 - val_loss: 0.0554 - 514ms/epoch - 3ms/step
# Epoch 9/100
# 165/165 - 1s - loss: 0.0196 - val_loss: 0.0529 - 506ms/epoch - 3ms/step
# Epoch 10/100
# 165/165 - 1s - loss: 0.0192 - val_loss: 0.0490 - 506ms/epoch - 3ms/step
# Epoch 11/100
# 165/165 - 1s - loss: 0.0188 - val_loss: 0.0454 - 521ms/epoch - 3ms/step
# Epoch 12/100
# 165/165 - 1s - loss: 0.0185 - val_loss: 0.0437 - 510ms/epoch - 3ms/step
# Epoch 13/100
# 165/165 - 1s - loss: 0.0183 - val_loss: 0.0441 - 507ms/epoch - 3ms/step
# Epoch 14/100
# 165/165 - 1s - loss: 0.0181 - val_loss: 0.0434 - 504ms/epoch - 3ms/step
# Epoch 15/100
# 165/165 - 1s - loss: 0.0180 - val_loss: 0.0434 - 506ms/epoch - 3ms/step
# Epoch 16/100
# 165/165 - 1s - loss: 0.0178 - val_loss: 0.0431 - 506ms/epoch - 3ms/step
# Epoch 17/100
# 165/165 - 1s - loss: 0.0177 - val_loss: 0.0426 - 522ms/epoch - 3ms/step
# Epoch 18/100
# 165/165 - 1s - loss: 0.0176 - val_loss: 0.0426 - 510ms/epoch - 3ms/step
# Epoch 19/100
# 165/165 - 1s - loss: 0.0175 - val_loss: 0.0429 - 511ms/epoch - 3ms/step
# Epoch 20/100
# 165/165 - 1s - loss: 0.0174 - val_loss: 0.0433 - 514ms/epoch - 3ms/step
# Epoch 21/100
# 165/165 - 1s - loss: 0.0174 - val_loss: 0.0436 - 511ms/epoch - 3ms/step
# Epoch 22/100
# 165/165 - 1s - loss: 0.0173 - val_loss: 0.0440 - 517ms/epoch - 3ms/step
# Epoch 23/100
# 165/165 - 1s - loss: 0.0173 - val_loss: 0.0436 - 528ms/epoch - 3ms/step
# Epoch 24/100
# 165/165 - 1s - loss: 0.0173 - val_loss: 0.0437 - 530ms/epoch - 3ms/step
# Epoch 25/100
# 165/165 - 1s - loss: 0.0172 - val_loss: 0.0435 - 503ms/epoch - 3ms/step
# Epoch 26/100
# 165/165 - 1s - loss: 0.0172 - val_loss: 0.0433 - 511ms/epoch - 3ms/step
# Epoch 27/100
# 165/165 - 1s - loss: 0.0171 - val_loss: 0.0433 - 505ms/epoch - 3ms/step
# Epoch 28/100
# 165/165 - 1s - loss: 0.0171 - val_loss: 0.0431 - 506ms/epoch - 3ms/step
# Epoch 29/100
# 165/165 - 1s - loss: 0.0171 - val_loss: 0.0430 - 509ms/epoch - 3ms/step
# Epoch 30/100
# 165/165 - 1s - loss: 0.0170 - val_loss: 0.0429 - 504ms/epoch - 3ms/step
# Epoch 31/100
# 165/165 - 1s - loss: 0.0170 - val_loss: 0.0424 - 500ms/epoch - 3ms/step
# Epoch 32/100
# 165/165 - 1s - loss: 0.0169 - val_loss: 0.0419 - 522ms/epoch - 3ms/step
# Epoch 33/100
# 165/165 - 1s - loss: 0.0169 - val_loss: 0.0421 - 502ms/epoch - 3ms/step
# Epoch 34/100
# 165/165 - 1s - loss: 0.0169 - val_loss: 0.0418 - 504ms/epoch - 3ms/step
# Epoch 35/100
# 165/165 - 1s - loss: 0.0169 - val_loss: 0.0417 - 505ms/epoch - 3ms/step
# Epoch 36/100
# 165/165 - 1s - loss: 0.0169 - val_loss: 0.0419 - 502ms/epoch - 3ms/step
# Epoch 37/100
# 165/165 - 1s - loss: 0.0168 - val_loss: 0.0418 - 504ms/epoch - 3ms/step
# Epoch 38/100
# 165/165 - 1s - loss: 0.0168 - val_loss: 0.0420 - 501ms/epoch - 3ms/step
# Epoch 39/100
# 165/165 - 1s - loss: 0.0168 - val_loss: 0.0414 - 506ms/epoch - 3ms/step
# Epoch 40/100
# 165/165 - 1s - loss: 0.0168 - val_loss: 0.0411 - 503ms/epoch - 3ms/step
# Epoch 41/100
# 165/165 - 1s - loss: 0.0167 - val_loss: 0.0409 - 500ms/epoch - 3ms/step
# Epoch 42/100
# 165/165 - 1s - loss: 0.0167 - val_loss: 0.0409 - 501ms/epoch - 3ms/step
# Epoch 43/100
# 165/165 - 0s - loss: 0.0167 - val_loss: 0.0407 - 483ms/epoch - 3ms/step
# Epoch 44/100
# 165/165 - 0s - loss: 0.0167 - val_loss: 0.0406 - 482ms/epoch - 3ms/step
# Epoch 45/100
# 165/165 - 0s - loss: 0.0166 - val_loss: 0.0406 - 478ms/epoch - 3ms/step
# Epoch 46/100
# 165/165 - 0s - loss: 0.0166 - val_loss: 0.0404 - 480ms/epoch - 3ms/step
# Epoch 47/100
# 165/165 - 0s - loss: 0.0166 - val_loss: 0.0406 - 485ms/epoch - 3ms/step
# Epoch 48/100
# 165/165 - 0s - loss: 0.0166 - val_loss: 0.0403 - 493ms/epoch - 3ms/step
# Epoch 49/100
# 165/165 - 0s - loss: 0.0165 - val_loss: 0.0400 - 497ms/epoch - 3ms/step
# Epoch 50/100
# 165/165 - 1s - loss: 0.0165 - val_loss: 0.0397 - 502ms/epoch - 3ms/step
# Epoch 51/100
# 165/165 - 0s - loss: 0.0165 - val_loss: 0.0400 - 497ms/epoch - 3ms/step
# Epoch 52/100
# 165/165 - 1s - loss: 0.0165 - val_loss: 0.0400 - 534ms/epoch - 3ms/step
# Epoch 53/100
# 165/165 - 0s - loss: 0.0165 - val_loss: 0.0395 - 496ms/epoch - 3ms/step
# Epoch 54/100
# 165/165 - 1s - loss: 0.0164 - val_loss: 0.0394 - 508ms/epoch - 3ms/step
# Epoch 55/100
# 165/165 - 0s - loss: 0.0164 - val_loss: 0.0388 - 499ms/epoch - 3ms/step
# Epoch 56/100
# 165/165 - 1s - loss: 0.0164 - val_loss: 0.0390 - 506ms/epoch - 3ms/step
# Epoch 57/100
# 165/165 - 1s - loss: 0.0163 - val_loss: 0.0390 - 503ms/epoch - 3ms/step
# Epoch 58/100
# 165/165 - 1s - loss: 0.0163 - val_loss: 0.0390 - 500ms/epoch - 3ms/step
# Epoch 59/100
# 165/165 - 1s - loss: 0.0163 - val_loss: 0.0388 - 502ms/epoch - 3ms/step
# Epoch 60/100
# 165/165 - 1s - loss: 0.0163 - val_loss: 0.0385 - 515ms/epoch - 3ms/step
# Epoch 61/100
# 165/165 - 1s - loss: 0.0163 - val_loss: 0.0384 - 507ms/epoch - 3ms/step
# Epoch 62/100
# 165/165 - 0s - loss: 0.0163 - val_loss: 0.0384 - 497ms/epoch - 3ms/step
# Epoch 63/100
# 165/165 - 0s - loss: 0.0162 - val_loss: 0.0386 - 499ms/epoch - 3ms/step
# Epoch 64/100
# 165/165 - 1s - loss: 0.0162 - val_loss: 0.0384 - 515ms/epoch - 3ms/step
# Epoch 65/100
# 165/165 - 1s - loss: 0.0162 - val_loss: 0.0385 - 508ms/epoch - 3ms/step
# Epoch 66/100
# 165/165 - 1s - loss: 0.0162 - val_loss: 0.0379 - 505ms/epoch - 3ms/step
# Epoch 67/100
# 165/165 - 1s - loss: 0.0162 - val_loss: 0.0377 - 511ms/epoch - 3ms/step
# Epoch 68/100
# 165/165 - 1s - loss: 0.0162 - val_loss: 0.0376 - 506ms/epoch - 3ms/step
# Epoch 69/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0373 - 514ms/epoch - 3ms/step
# Epoch 70/100
# 165/165 - 0s - loss: 0.0161 - val_loss: 0.0370 - 496ms/epoch - 3ms/step
# Epoch 71/100
# 165/165 - 0s - loss: 0.0161 - val_loss: 0.0371 - 496ms/epoch - 3ms/step
# Epoch 72/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0370 - 507ms/epoch - 3ms/step
# Epoch 73/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0368 - 533ms/epoch - 3ms/step
# Epoch 74/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0368 - 505ms/epoch - 3ms/step
# Epoch 75/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0365 - 510ms/epoch - 3ms/step
# Epoch 76/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0362 - 508ms/epoch - 3ms/step
# Epoch 77/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0358 - 530ms/epoch - 3ms/step
# Epoch 78/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0356 - 521ms/epoch - 3ms/step
# Epoch 79/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0353 - 511ms/epoch - 3ms/step
# Epoch 80/100
# 165/165 - 0s - loss: 0.0160 - val_loss: 0.0351 - 496ms/epoch - 3ms/step
# Epoch 81/100
# 165/165 - 0s - loss: 0.0161 - val_loss: 0.0348 - 490ms/epoch - 3ms/step
# Epoch 82/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0346 - 516ms/epoch - 3ms/step
# Epoch 83/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0348 - 511ms/epoch - 3ms/step
# Epoch 84/100
# 165/165 - 1s - loss: 0.0161 - val_loss: 0.0348 - 512ms/epoch - 3ms/step
# Epoch 85/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0346 - 544ms/epoch - 3ms/step
# Epoch 86/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0346 - 528ms/epoch - 3ms/step
# Epoch 87/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0347 - 536ms/epoch - 3ms/step
# Epoch 88/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0344 - 525ms/epoch - 3ms/step
# Epoch 89/100
# 165/165 - 0s - loss: 0.0159 - val_loss: 0.0348 - 498ms/epoch - 3ms/step
# Epoch 90/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0348 - 525ms/epoch - 3ms/step
# Epoch 91/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0340 - 524ms/epoch - 3ms/step
# Epoch 92/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0342 - 540ms/epoch - 3ms/step
# Epoch 93/100
# 165/165 - 1s - loss: 0.0160 - val_loss: 0.0339 - 529ms/epoch - 3ms/step
# Epoch 94/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0338 - 569ms/epoch - 3ms/step
# Epoch 95/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0336 - 601ms/epoch - 4ms/step
# Epoch 96/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0335 - 568ms/epoch - 3ms/step
# Epoch 97/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0335 - 511ms/epoch - 3ms/step
# Epoch 98/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0329 - 521ms/epoch - 3ms/step
# Epoch 99/100
# 165/165 - 1s - loss: 0.0159 - val_loss: 0.0337 - 515ms/epoch - 3ms/step
# Epoch 100/100
# 165/165 - 1s - loss: 0.0158 - val_loss: 0.0336 - 512ms/epoch - 3ms/step

# %%
from keras.wrappers.scikit_learn import KerasClassifier

def define_model(dropout_rate=0.0,neurons=10,x_grid=x_grid):
    model = Sequential()
    model.add(LSTM(units=neurons,return_sequences=True,input_shape=(x_grid.shape[1],1)))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units=neurons,return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units=neurons))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=1))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['acc'])
    return model

model = KerasClassifier(build_fn = define_model,verbose=1)
dropout_rate=[0.2,0.4]
neurons=[50,100,150]
batch_size=[32,64]
epochs = [50,100]

param_grid=dict(dropout_rate=dropout_rate,neurons=neurons,batch_size=batch_size,epochs=epochs)

grid=GridSearchCV(estimator=model,param_grid=param_grid,cv=3)
grid_result=grid.fit(x_grid,y_grid)

# %%
from keras.wrappers.scikit_learn import KerasClassifier

# %%
params = {'dropout_rate': [0.0, 0.2, 0.4], 'n_neurons': [5, 10, 25, 50], 'batch_size': [8, 16, 32]}

param_list = [(x, y, z) for x in params['dropout_rate'] for y in params['n_neurons'] for z in params['batch_size']]
len(param_list)
# Out:
# 36

# %%
params = {'dropout_rate': [0.0, 0.2, 0.4], 'n_neurons': [5, 10, 25, 50], 'batch_size': [8, 16, 32]}

param_list = [(x, y, z) for x in params['dropout_rate'] for y in params['n_neurons'] for z in params['batch_size']]

preds = {}
scores = {}
history_dict = {}
i = 0

def lstm_model(dropout_rate=0.0, n_neurons=50, n_days=n_days, n_features=n_features, n_epochs=50, batch_size=32):
  # Sequential model is appropriate to design LSTM RNN
  model = Sequential()
  # train_X : 3D tensor (samples, lag_hours, feature)
  # single input_shape = (lag_days, feature)
  model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
  model.add(Dropout(dropout_rate))
  model.add(LSTM(n_neurons, return_sequences=True))
  model.add(Dropout(dropout_rate))
  model.add(LSTM(n_neurons, return_sequences=True))
  model.add(Dropout(dropout_rate))
  model.add(LSTM(n_neurons))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1))  # 1 neuron in the output layer
  model.compile(loss='mae', optimizer='adam')

  return model

for params in param_list:

  print(params)
  
  preds[params] = []
  scores[params] = []
  
  model = lstm_model(dropout_rate=params[0], n_neurons=params[1], batch_size=params[2])
  
  history = model.fit(train_X, train_y, validation_data=(val_X, val_y), verbose=2, shuffle=False)

  y_pred = model.predict(train_X)
  preds[params] = y_pred
  score = np.sqrt(metrics.mean_squared_error(train_y, y_pred))
  scores[params] = score
  history_dict[params] = history
  
  i += 1
# Out:
# (0.0, 5, 8)
# 124/124 - 13s - loss: 0.1798 - val_loss: 0.3334 - 13s/epoch - 107ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0
ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0.4, 5, 16)
# 124/124 - 11s - loss: 0.1821 - val_loss: 0.3308 - 11s/epoch - 89ms/step
# 124/124 [==============================] - 2s 2ms/step
# (0.4, 5, 32)
# 124/124 - 11s - loss: 0.1977 - val_loss: 0.3506 - 11s/epoch - 88ms/step
# 124/124 [==============================] - 2s 2ms/step
# (0.4, 10, 8)
# 124/124 - 15s - loss: 0.1643 - val_loss: 0.3516 - 15s/epoch - 120ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0.4, 10, 16)
# 124/124 - 11s - loss: 0.1694 - val_loss: 0.3056 - 11s/epoch - 89ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0.4, 10, 32)
# 124/124 - 11s - loss: 0.1813 - val_loss: 0.3493 - 11s/epoch - 88ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0.4, 25, 8)
# 124/124 - 11s - loss: 0.1567 - val_loss: 0.3073 - 11s/epoch - 90ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0.4, 25, 16)
# 124/124 - 16s - loss: 0.1521 - val_loss: 0.3219 - 16s/epoch - 127ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0.4, 25, 32)
# 124/124 - 11s - loss: 0.1557 - val_loss: 0.3306 - 11s/epoch - 90ms/step
# 124/124 [==============================] - 2s 3ms/step
# (0.4, 50, 8)
# 124/124 - 12s - loss: 0.1567 - val_loss: 0.3007 - 12s/epoch - 93ms/step
# 124/124 [==============================] - 2s 4ms/step
# (0.4, 50, 16)
# 124/124 - 11s - loss: 0.1536 - val_loss: 0.3218 - 11s/epoch - 92ms/step
# 124/124 [==============================] - 2s 4ms/step
# (0.4, 50, 32)
# 124/124 - 11s - loss: 0.1515 - val_loss: 0.2938 - 11s/epoch - 92ms/step
# 124/124 [==============================] - 2s 4ms/step

# %%
list(history_dict.values())[0].history
# Out:
# {'loss': [0.17984779179096222], 'val_loss': [0.33338662981987]}

# %%
params = {'dropout_rate': [0.0, 0.2, 0.4], 'n_neurons': [5, 10, 25, 50], 'batch_size': [8, 16, 32]}

param_list = [(x, y, z) for x in params['dropout_rate'] for y in params['n_neurons'] for z in params['batch_size']]

preds2 = {}
scores2 = {}
history_dict2 = {}
i = 0

def lstm_model(dropout_rate=0.0, n_neurons=50, n_days=n_days, n_features=n_features, n_epochs=50, batch_size=32):
  # Sequential model is appropriate to design LSTM RNN
  model = Sequential()
  # train_X : 3D tensor (samples, lag_hours, feature)
  # single input_shape = (lag_days, feature)
  model.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
  model.add(Dropout(dropout_rate))
  model.add(LSTM(n_neurons, return_sequences=True))
  model.add(Dropout(dropout_rate))
  model.add(LSTM(n_neurons, return_sequences=True))
  model.add(Dropout(dropout_rate))
  model.add(LSTM(n_neurons))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1))  # 1 neuron in the output layer
  model.compile(loss='mae', optimizer='adam')

  return model

for params in param_list:

  print(params)
  
  model = lstm_model(dropout_rate=params[0], n_neurons=params[1], batch_size=params[2])
  
  history = model.fit(train_X, train_y, epochs=50, validation_data=(val_X, val_y), verbose=2, shuffle=False)

  y_pred = model.predict(train_X)
  y_pred_val = model.predict(val_X)
  preds2[params] = (y_pred, y_pred_val)
  score = np.sqrt(metrics.mean_squared_error(train_y, y_pred))
  score_val = np.sqrt(metrics.mean_squared_error(val_y, y_pred_val))
  scores2[params] = (score, score_val)
  history_dict2[params] = history.history
  
  i += 1
# Out:
# (0.0, 5, 8)
# Epoch 1/50
# 124/124 - 13s - loss: 0.1548 - val_loss: 0.3331 - 13s/epoch - 103ms/step
# Epoch 2/50
# 124/124 - 1s - loss: 0.
ms/step
# Epoch 21/50
# 124/124 - 2s - loss: 0.1058 - val_loss: 0.1609 - 2s/epoch - 13ms/step
# Epoch 22/50
# 124/124 - 2s - loss: 0.1056 - val_loss: 0.1658 - 2s/epoch - 12ms/step
# Epoch 23/50
# 124/124 - 2s - loss: 0.1051 - val_loss: 0.1578 - 2s/epoch - 12ms/step
# Epoch 24/50
# 124/124 - 2s - loss: 0.1052 - val_loss: 0.1548 - 2s/epoch - 13ms/step
# Epoch 25/50
# 124/124 - 2s - loss: 0.1046 - val_loss: 0.1484 - 2s/epoch - 13ms/step
# Epoch 26/50
# 124/124 - 2s - loss: 0.1047 - val_loss: 0.1565 - 2s/epoch - 13ms/step
# Epoch 27/50
# 124/124 - 2s - loss: 0.1044 - val_loss: 0.1542 - 2s/epoch - 13ms/step
# Epoch 28/50
# 124/124 - 2s - loss: 0.1046 - val_loss: 0.1551 - 2s/epoch - 13ms/step
# Epoch 29/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1567 - 2s/epoch - 13ms/step
# Epoch 30/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1649 - 2s/epoch - 13ms/step
# Epoch 31/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1584 - 2s/epoch - 13ms/step
# Epoch 32/50
# 124/124 - 2s - loss: 0.1034 - val_loss: 0.1607 - 2s/epoch - 13ms/step
# Epoch 33/50
# 124/124 - 2s - loss: 0.1034 - val_loss: 0.1625 - 2s/epoch - 13ms/step
# Epoch 34/50
# 124/124 - 2s - loss: 0.1030 - val_loss: 0.1665 - 2s/epoch - 13ms/step
# Epoch 35/50
# 124/124 - 2s - loss: 0.1027 - val_loss: 0.1615 - 2s/epoch - 13ms/step
# Epoch 36/50
# 124/124 - 2s - loss: 0.1025 - val_loss: 0.1601 - 2s/epoch - 13ms/step
# Epoch 37/50
# 124/124 - 2s - loss: 0.1025 - val_loss: 0.1626 - 2s/epoch - 13ms/step
# Epoch 38/50
# 124/124 - 2s - loss: 0.1024 - val_loss: 0.1621 - 2s/epoch - 13ms/step
# Epoch 39/50
# 124/124 - 2s - loss: 0.1018 - val_loss: 0.1667 - 2s/epoch - 13ms/step
# Epoch 40/50
# 124/124 - 2s - loss: 0.1019 - val_loss: 0.1632 - 2s/epoch - 12ms/step
# Epoch 41/50
# 124/124 - 2s - loss: 0.1022 - val_loss: 0.1632 - 2s/epoch - 13ms/step
# Epoch 42/50
# 124/124 - 2s - loss: 0.1020 - val_loss: 0.1660 - 2s/epoch - 12ms/step
# Epoch 43/50
# 124/124 - 2s - loss: 0.1021 - val_loss: 0.1628 - 2s/epoch - 12ms/step
# Epoch 44/50
# 124/124 - 2s - loss: 0.1019 - val_loss: 0.1603 - 2s/epoch - 12ms/step
# Epoch 45/50
# 124/124 - 1s - loss: 0.1018 - val_loss: 0.1609 - 1s/epoch - 12ms/step
# Epoch 46/50
# 124/124 - 2s - loss: 0.1016 - val_loss: 0.1591 - 2s/epoch - 12ms/step
# Epoch 47/50
# 124/124 - 2s - loss: 0.1014 - val_loss: 0.1575 - 2s/epoch - 12ms/step
# Epoch 48/50
# 124/124 - 2s - loss: 0.1012 - val_loss: 0.1554 - 2s/epoch - 13ms/step
# Epoch 49/50
# 124/124 - 2s - loss: 0.1011 - val_loss: 0.1569 - 2s/epoch - 13ms/step
# Epoch 50/50
# 124/124 - 2s - loss: 0.1014 - val_loss: 0.1552 - 2s/epoch - 14ms/step
# 124/124 [==============================] - 2s 4ms/step
# 31/31 [==============================] - 0s 4ms/step
# (0.0, 50, 32)
# Epoch 1/50
# 124/124 - 12s - loss: 0.1498 - val_loss: 0.2938 - 12s/epoch - 94ms/step
# Epoch 2/50
# 124/124 - 2s - loss: 0.1261 - val_loss: 0.2276 - 2s/epoch - 12ms/step
# Epoch 3/50
# 124/124 - 2s - loss: 0.1188 - val_loss: 0.2104 - 2s/epoch - 12ms/step
# Epoch 4/50
# 124/124 - 2s - loss: 0.1160 - val_loss: 0.2075 - 2s/epoch - 12ms/step
# Epoch 5/50
# 124/124 - 2s - loss: 0.1145 - val_loss: 0.2030 - 2s/epoch - 12ms/step
# Epoch 6/50
# 124/124 - 1s - loss: 0.1136 - val_loss: 0.1872 - 1s/epoch - 12ms/step
# Epoch 7/50
# 124/124 - 2s - loss: 0.1123 - val_loss: 0.1863 - 2s/epoch - 13ms/step
# Epoch 8/50
# 124/124 - 2s - loss: 0.1116 - val_loss: 0.1912 - 2s/epoch - 13ms/step
# Epoch 9/50
# 124/124 - 2s - loss: 0.1109 - val_loss: 0.1878 - 2s/epoch - 13ms/step
# Epoch 10/50
# 124/124 - 2s - loss: 0.1106 - val_loss: 0.1940 - 2s/epoch - 12ms/step
# Epoch 11/50
# 124/124 - 2s - loss: 0.1102 - val_loss: 0.1941 - 2s/epoch - 12ms/step
# Epoch 12/50
# 124/124 - 2s - loss: 0.1116 - val_loss: 0.2168 - 2s/epoch - 12ms/step
# Epoch 13/50
# 124/124 - 2s - loss: 0.1096 - val_loss: 0.1969 - 2s/epoch - 12ms/step
# Epoch 14/50
# 124/124 - 2s - loss: 0.1081 - val_loss: 0.1908 - 2s/epoch - 12ms/step
# Epoch 15/50
# 124/124 - 2s - loss: 0.1081 - val_loss: 0.1757 - 2s/epoch - 12ms/step
# Epoch 16/50
# 124/124 - 1s - loss: 0.1082 - val_loss: 0.1906 - 1s/epoch - 12ms/step
# Epoch 17/50
# 124/124 - 1s - loss: 0.1081 - val_loss: 0.1967 - 1s/epoch - 12ms/step
# Epoch 18/50
# 124/124 - 1s - loss: 0.1067 - val_loss: 0.1772 - 1s/epoch - 12ms/step
# Epoch 19/50
# 124/124 - 2s - loss: 0.1068 - val_loss: 0.1755 - 2s/epoch - 13ms/step
# Epoch 20/50
# 124/124 - 1s - loss: 0.1064 - val_loss: 0.1620 - 1s/epoch - 12ms/step
# Epoch 21/50
# ...
# Epoch 12/50
# 124/124 - 1s - loss: 0.1145 - val_loss: 0.1935 - 1s/epoch - 10ms/step
# Epoch 13/50
# 124/124 - 1s - loss: 0.1151 - val_loss: 0.1891 - 1s/epoch - 10ms/step
# Epoch 14/50
# 124/124 - 1s - loss: 0.1146 - val_loss: 0.1870 - 1s/epoch - 10ms/step
# Epoch 15/50
# 124/124 - 1s - loss: 0.1147 - val_loss: 0.1952 - 1s/epoch - 10ms/step
# Epoch 16/50
# 124/124 - 1s - loss: 0.1136 - val_loss: 0.1874 - 1s/epoch - 10ms/step
# Epoch 17/50
# 124/124 - 1s - loss: 0.1142 - val_loss: 0.1887 - 1s/epoch - 10ms/step
# Epoch 18/50
# 124/124 - 1s - loss: 0.1126 - val_loss: 0.1860 - 1s/epoch - 10ms/step
# Epoch 19/50
# 124/124 - 1s - loss: 0.1125 - val_loss: 0.1759 - 1s/epoch - 10ms/step
# Epoch 20/50
# 124/124 - 1s - loss: 0.1127 - val_loss: 0.1807 - 1s/epoch - 10ms/step
# Epoch 21/50
# 124/124 - 1s - loss: 0.1116 - val_loss: 0.1905 - 1s/epoch - 10ms/step
# Epoch 22/50
# 124/124 - 1s - loss: 0.1118 - val_loss: 0.1765 - 1s/epoch - 11ms/step
# Epoch 23/50
# 124/124 - 1s - loss: 0.1107 - val_loss: 0.1888 - 1s/epoch - 10ms/step
# Epoch 24/50
# 124/124 - 1s - loss: 0.1106 - val_loss: 0.1716 - 1s/epoch - 10ms/step
# Epoch 25/50
# 124/124 - 1s - loss: 0.1110 - val_loss: 0.1715 - 1s/epoch - 11ms/step
# Epoch 26/50
# 124/124 - 1s - loss: 0.1107 - val_loss: 0.1664 - 1s/epoch - 11ms/step
# Epoch 27/50
# 124/124 - 1s - loss: 0.1101 - val_loss: 0.1586 - 1s/epoch - 11ms/step
# Epoch 28/50
# 124/124 - 1s - loss: 0.1106 - val_loss: 0.1689 - 1s/epoch - 12ms/step
# Epoch 29/50
# 124/124 - 1s - loss: 0.1102 - val_loss: 0.1657 - 1s/epoch - 11ms/step
# Epoch 30/50
# 124/124 - 1s - loss: 0.1089 - val_loss: 0.1579 - 1s/epoch - 10ms/step
# Epoch 31/50
# 124/124 - 1s - loss: 0.1088 - val_loss: 0.1642 - 1s/epoch - 11ms/step
# Epoch 32/50
# 124/124 - 1s - loss: 0.1102 - val_loss: 0.1648 - 1s/epoch - 10ms/step
# Epoch 33/50
# 124/124 - 1s - loss: 0.1096 - val_loss: 0.1629 - 1s/epoch - 11ms/step
# Epoch 34/50
# 124/124 - 1s - loss: 0.1076 - val_loss: 0.1618 - 1s/epoch - 11ms/step
# Epoch 35/50
# 124/124 - 1s - loss: 0.1075 - val_loss: 0.1582 - 1s/epoch - 10ms/step
# Epoch 36/50
# 124/124 - 1s - loss: 0.1078 - val_loss: 0.1592 - 1s/epoch - 10ms/step
# Epoch 37/50
# 124/124 - 1s - loss: 0.1084 - val_loss: 0.1638 - 1s/epoch - 10ms/step
# Epoch 38/50
# 124/124 - 1s - loss: 0.1071 - val_loss: 0.1617 - 1s/epoch - 10ms/step
# Epoch 39/50
# 124/124 - 1s - loss: 0.1075 - val_loss: 0.1518 - 1s/epoch - 10ms/step
# Epoch 40/50
# 124/124 - 1s - loss: 0.1076 - val_loss: 0.1646 - 1s/epoch - 10ms/step
# Epoch 41/50
# 124/124 - 1s - loss: 0.1071 - val_loss: 0.1679 - 1s/epoch - 10ms/step
# Epoch 42/50
# 124/124 - 1s - loss: 0.1058 - val_loss: 0.1490 - 1s/epoch - 10ms/step
# Epoch 43/50
# 124/124 - 1s - loss: 0.1061 - val_loss: 0.1624 - 1s/epoch - 10ms/step
# Epoch 44/50
# 124/124 - 1s - loss: 0.1061 - val_loss: 0.1566 - 1s/epoch - 10ms/step
# Epoch 45/50
# 124/124 - 1s - loss: 0.1059 - val_loss: 0.1656 - 1s/epoch - 11ms/step
# Epoch 46/50
# 124/124 - 1s - loss: 0.1059 - val_loss: 0.1579 - 1s/epoch - 10ms/step
# Epoch 47/50
# 124/124 - 1s - loss: 0.1074 - val_loss: 0.1597 - 1s/epoch - 10ms/step
# Epoch 48/50
# 124/124 - 1s - loss: 0.1054 - val_loss: 0.1558 - 1s/epoch - 10ms/step
# Epoch 49/50
# 124/124 - 1s - loss: 0.1058 - val_loss: 0.1601 - 1s/epoch - 10ms/step
# Epoch 50/50
# 124/124 - 1s - loss: 0.1054 - val_loss: 0.1612 - 1s/epoch - 10ms/step
# 124/124 [==============================] - 2s 3ms/step
# 31/31 [==============================] - 0s 3ms/step
# (0.4, 50, 8)
# Epoch 1/50
# 124/124 - 12s - loss: 0.1531 - val_loss: 0.3300 - 12s/epoch - 94ms/step
# Epoch 2/50
# 124/124 - 2s - loss: 0.1299 - val_loss: 0.2481 - 2s/epoch - 14ms/step
# Epoch 3/50
# 124/124 - 2s - loss: 0.1232 - val_loss: 0.2267 - 2s/epoch - 14ms/step
# Epoch 4/50
# 124/124 - 2s - loss: 0.1214 - val_loss: 0.1965 - 2s/epoch - 14ms/step
# Epoch 5/50
# 124/124 - 2s - loss: 0.1191 - val_loss: 0.1982 - 2s/epoch - 14ms/step
# Epoch 6/50
# 124/124 - 2s - loss: 0.1179 - val_loss: 0.2410 - 2s/epoch - 13ms/step
# Epoch 7/50
# 124/124 - 2s - loss: 0.1180 - val_loss: 0.1743 - 2s/epoch - 13ms/step
# Epoch 8/50
# 124/124 - 2s - loss: 0.1152 - val_loss: 0.2217 - 2s/epoch - 14ms/step
# Epoch 9/50
# 124/124 - 2s - loss: 0.1155 - val_loss: 0.1841 - 2s/epoch - 14ms/step
# Epoch 10/50
# 124/124 - 2s - loss: 0.1144 - val_loss: 0.2054 - 2s/epoch - 13ms/step
# Epoch 11/50
# 124/124 - 2s - loss: 0.1139 - val_loss: 0.1932 - 2s/epoch - 13ms/step
# Epoch 12/50
# 124/124 - 2s - loss: 0.1127 - val_loss: 0.1813 - 2s/epoch - 13ms/step
# Epoch 13/50
# 124/124 - 2s - loss: 0.1142 - val_loss: 0.2237 - 2s/epoch - 13ms/step
# Epoch 14/50
# 124/124 - 2s - loss: 0.1141 - val_loss: 0.1879 - 2s/epoch - 13ms/step
# Epoch 15/50
# 124/124 - 2s - loss: 0.1141 - val_loss: 0.2054 - 2s/epoch - 13ms/step
# Epoch 16/50
# 124/124 - 2s - loss: 0.1127 - val_loss: 0.1850 - 2s/epoch - 13ms/step
# Epoch 17/50
# 124/124 - 2s - loss: 0.1124 - val_loss: 0.1865 - 2s/epoch - 13ms/step
# Epoch 18/50
# 124/124 - 2s - loss: 0.1141 - val_loss: 0.1831 - 2s/epoch - 13ms/step
# Epoch 19/50
# 124/124 - 2s - loss: 0.1115 - val_loss: 0.1716 - 2s/epoch - 13ms/step
# Epoch 20/50
# 124/124 - 2s - loss: 0.1115 - val_loss: 0.1773 - 2s/epoch - 13ms/step
# Epoch 21/50
# 124/124 - 2s - loss: 0.1099 - val_loss: 0.1781 - 2s/epoch - 13ms/step
# Epoch 22/50
# 124/124 - 2s - loss: 0.1109 - val_loss: 0.1826 - 2s/epoch - 13ms/step
# Epoch 23/50
# 124/124 - 2s - loss: 0.1102 - val_loss: 0.1735 - 2s/epoch - 13ms/step
# Epoch 24/50
# 124/124 - 2s - loss: 0.1089 - val_loss: 0.1530 - 2s/epoch - 13ms/step
# Epoch 25/50
# 124/124 - 2s - loss: 0.1086 - val_loss: 0.1473 - 2s/epoch - 13ms/step
# Epoch 26/50
# 124/124 - 2s - loss: 0.1078 - val_loss: 0.1443 - 2s/epoch - 13ms/step
# Epoch 27/50
# 124/124 - 2s - loss: 0.1077 - val_loss: 0.1553 - 2s/epoch - 13ms/step
# Epoch 28/50
# 124/124 - 2s - loss: 0.1077 - val_loss: 0.1497 - 2s/epoch - 13ms/step
# Epoch 29/50
# 124/124 - 2s - loss: 0.1065 - val_loss: 0.1594 - 2s/epoch - 13ms/step
# Epoch 30/50
# 124/124 - 2s - loss: 0.1073 - val_loss: 0.1532 - 2s/epoch - 13ms/step
# Epoch 31/50
# 124/124 - 2s - loss: 0.1067 - val_loss: 0.1518 - 2s/epoch - 13ms/step
# Epoch 32/50
# 124/124 - 2s - loss: 0.1062 - val_loss: 0.1591 - 2s/epoch - 13ms/step
# Epoch 33/50
# 124/124 - 2s - loss: 0.1057 - val_loss: 0.1524 - 2s/epoch - 13ms/step
# Epoch 34/50
# 124/124 - 2s - loss: 0.1053 - val_loss: 0.1466 - 2s/epoch - 13ms/step
# Epoch 35/50
# 124/124 - 2s - loss: 0.1065 - val_loss: 0.1479 - 2s/epoch - 13ms/step
# Epoch 36/50
# 124/124 - 2s - loss: 0.1064 - val_loss: 0.1526 - 2s/epoch - 13ms/step
# Epoch 37/50
# 124/124 - 2s - loss: 0.1054 - val_loss: 0.1425 - 2s/epoch - 13ms/step
# Epoch 38/50
# 124/124 - 2s - loss: 0.1059 - val_loss: 0.1473 - 2s/epoch - 13ms/step
# Epoch 39/50
# 124/124 - 2s - loss: 0.1067 - val_loss: 0.1523 - 2s/epoch - 13ms/step
# Epoch 40/50
# 124/124 - 2s - loss: 0.1059 - val_loss: 0.1595 - 2s/epoch - 13ms/step
# Epoch 41/50
# 124/124 - 2s - loss: 0.1051 - val_loss: 0.1480 - 2s/epoch - 14ms/step
# Epoch 42/50
# 124/124 - 2s - loss: 0.1054 - val_loss: 0.1519 - 2s/epoch - 14ms/step
# Epoch 43/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1472 - 2s/epoch - 13ms/step
# Epoch 44/50
# 124/124 - 2s - loss: 0.1054 - val_loss: 0.1484 - 2s/epoch - 14ms/step
# Epoch 45/50
# 124/124 - 2s - loss: 0.1041 - val_loss: 0.1491 - 2s/epoch - 14ms/step
# Epoch 46/50
# 124/124 - 2s - loss: 0.1042 - val_loss: 0.1456 - 2s/epoch - 13ms/step
# Epoch 47/50
# 124/124 - 2s - loss: 0.1046 - val_loss: 0.1465 - 2s/epoch - 14ms/step
# Epoch 48/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1426 - 2s/epoch - 13ms/step
# Epoch 49/50
# 124/124 - 2s - loss: 0.1036 - val_loss: 0.1463 - 2s/epoch - 13ms/step
# Epoch 50/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1488 - 2s/epoch - 13ms/step
# 124/124 [==============================] - 2s 4ms/step
# 31/31 [==============================] - 0s 4ms/step
# (0.4, 50, 16)
# Epoch 1/50
# 124/124 - 11s - loss: 0.1562 - val_loss: 0.3196 - 11s/epoch - 91ms/step
# Epoch 2/50
# 124/124 - 2s - loss: 0.1306 - val_loss: 0.2519 - 2s/epoch - 13ms/step
# Epoch 3/50
# 124/124 - 2s - loss: 0.1237 - val_loss: 0.2266 - 2s/epoch - 13ms/step
# Epoch 4/50
# 124/124 - 2s - loss: 0.1217 - val_loss: 0.2385 - 2s/epoch - 13ms/step
# Epoch 5/50
# 124/124 - 2s - loss: 0.1194 - val_loss: 0.1919 - 2s/epoch - 13ms/step
# Epoch 6/50
# 124/124 - 2s - loss: 0.1175 - val_loss: 0.2044 - 2s/epoch - 13ms/step
# Epoch 7/50
# 124/124 - 2s - loss: 0.1151 - val_loss: 0.1829 - 2s/epoch - 13ms/step
# Epoch 8/50
# 124/124 - 2s - loss: 0.1150 - val_loss: 0.2052 - 2s/epoch - 13ms/step
# Epoch 9/50
# 124/124 - 2s - loss: 0.1161 - val_loss: 0.2200 - 2s/epoch - 13ms/step
# Epoch 10/50
# 124/124 - 2s - loss: 0.1145 - val_loss: 0.1790 - 2s/epoch - 13ms/step
# Epoch 11/50
# 124/124 - 2s - loss: 0.1149 - val_loss: 0.2244 - 2s/epoch - 13ms/step
# Epoch 12/50
# 124/124 - 2s - loss: 0.1138 - val_loss: 0.1867 - 2s/epoch - 13ms/step
# Epoch 13/50
# 124/124 - 2s - loss: 0.1126 - val_loss: 0.1828 - 2s/epoch - 13ms/step
# Epoch 14/50
# 124/124 - 2s - loss: 0.1120 - val_loss: 0.1704 - 2s/epoch - 13ms/step
# Epoch 15/50
# 124/124 - 2s - loss: 0.1122 - val_loss: 0.1808 - 2s/epoch - 13ms/step
# Epoch 16/50
# 124/124 - 2s - loss: 0.1110 - val_loss: 0.1802 - 2s/epoch - 13ms/step
# Epoch 17/50
# 124/124 - 2s - loss: 0.1115 - val_loss: 0.1753 - 2s/epoch - 13ms/step
# Epoch 18/50
# 124/124 - 2s - loss: 0.1101 - val_loss: 0.1766 - 2s/epoch - 13ms/step
# Epoch 19/50
# 124/124 - 2s - loss: 0.1089 - val_loss: 0.1676 - 2s/epoch - 13ms/step
# Epoch 20/50
# 124/124 - 2s - loss: 0.1095 - val_loss: 0.1701 - 2s/epoch - 13ms/step
# Epoch 21/50
# 124/124 - 2s - loss: 0.1111 - val_loss: 0.1818 - 2s/epoch - 14ms/step
# Epoch 22/50
# 124/124 - 2s - loss: 0.1103 - val_loss: 0.1804 - 2s/epoch - 13ms/step
# Epoch 23/50
# 124/124 - 2s - loss: 0.1083 - val_loss: 0.1697 - 2s/epoch - 14ms/step
# Epoch 24/50
# 124/124 - 2s - loss: 0.1086 - val_loss: 0.1674 - 2s/epoch - 14ms/step
# Epoch 25/50
# 124/124 - 2s - loss: 0.1088 - val_loss: 0.1689 - 2s/epoch - 13ms/step
# Epoch 26/50
# 124/124 - 2s - loss: 0.1076 - val_loss: 0.1672 - 2s/epoch - 13ms/step
# Epoch 27/50
# 124/124 - 2s - loss: 0.1071 - val_loss: 0.1697 - 2s/epoch - 13ms/step
# Epoch 28/50
# 124/124 - 2s - loss: 0.1083 - val_loss: 0.1706 - 2s/epoch - 13ms/step
# Epoch 29/50
# 124/124 - 2s - loss: 0.1069 - val_loss: 0.1684 - 2s/epoch - 13ms/step
# Epoch 30/50
# 124/124 - 2s - loss: 0.1072 - val_loss: 0.1626 - 2s/epoch - 13ms/step
# Epoch 31/50
# 124/124 - 2s - loss: 0.1059 - val_loss: 0.1529 - 2s/epoch - 13ms/step
# Epoch 32/50
# 124/124 - 2s - loss: 0.1060 - val_loss: 0.1613 - 2s/epoch - 13ms/step
# Epoch 33/50
# 124/124 - 2s - loss: 0.1060 - val_loss: 0.1601 - 2s/epoch - 13ms/step
# Epoch 34/50
# 124/124 - 2s - loss: 0.1059 - val_loss: 0.1663 - 2s/epoch - 13ms/step
# Epoch 35/50
# 124/124 - 2s - loss: 0.1053 - val_loss: 0.1544 - 2s/epoch - 13ms/step
# Epoch 36/50
# 124/124 - 2s - loss: 0.1054 - val_loss: 0.1542 - 2s/epoch - 13ms/step
# Epoch 37/50
# 124/124 - 2s - loss: 0.1062 - val_loss: 0.1595 - 2s/epoch - 13ms/step
# Epoch 38/50
# 124/124 - 2s - loss: 0.1041 - val_loss: 0.1484 - 2s/epoch - 13ms/step
# Epoch 39/50
# 124/124 - 2s - loss: 0.1047 - val_loss: 0.1450 - 2s/epoch - 13ms/step
# Epoch 40/50
# 124/124 - 2s - loss: 0.1040 - val_loss: 0.1567 - 2s/epoch - 13ms/step
# Epoch 41/50
# 124/124 - 2s - loss: 0.1051 - val_loss: 0.1529 - 2s/epoch - 13ms/step
# Epoch 42/50
# 124/124 - 2s - loss: 0.1043 - val_loss: 0.1521 - 2s/epoch - 13ms/step
# Epoch 43/50
# 124/124 - 2s - loss: 0.1035 - val_loss: 0.1453 - 2s/epoch - 13ms/step
# Epoch 44/50
# 124/124 - 2s - loss: 0.1040 - val_loss: 0.1579 - 2s/epoch - 13ms/step
# Epoch 45/50
# 124/124 - 2s - loss: 0.1032 - val_loss: 0.1524 - 2s/epoch - 12ms/step
# Epoch 46/50
# 124/124 - 2s - loss: 0.1034 - val_loss: 0.1570 - 2s/epoch - 13ms/step
# Epoch 47/50
# 124/124 - 2s - loss: 0.1042 - val_loss: 0.1460 - 2s/epoch - 13ms/step
# Epoch 48/50
# 124/124 - 2s - loss: 0.1034 - val_loss: 0.1530 - 2s/epoch - 14ms/step
# Epoch 49/50
# 124/124 - 2s - loss: 0.1049 - val_loss: 0.1467 - 2s/epoch - 14ms/step
# Epoch 50/50
# 124/124 - 2s - loss: 0.1034 - val_loss: 0.1424 - 2s/epoch - 14ms/step
# 124/124 [==============================] - 2s 4ms/step
# 31/31 [==============================] - 0s 4ms/step
# (0.4, 50, 32)
# Epoch 1/50
# 124/124 - 12s - loss: 0.1527 - val_loss: 0.2828 - 12s/epoch - 96ms/step
# Epoch 2/50
# 124/124 - 2s - loss: 0.1284 - val_loss: 0.2189 - 2s/epoch - 14ms/step
# Epoch 3/50
# 124/124 - 2s - loss: 0.1224 - val_loss: 0.2187 - 2s/epoch - 15ms/step
# Epoch 4/50
# 124/124 - 2s - loss: 0.1231 - val_loss: 0.2244 - 2s/epoch - 13ms/step
# Epoch 5/50
# 124/124 - 2s - loss: 0.1180 - val_loss: 0.2085 - 2s/epoch - 13ms/step
# Epoch 6/50
# 124/124 - 2s - loss: 0.1195 - val_loss: 0.2660 - 2s/epoch - 14ms/step
# Epoch 7/50
# 124/124 - 2s - loss: 0.1188 - val_loss: 0.1686 - 2s/epoch - 15ms/step
# Epoch 8/50
# 124/124 - 2s - loss: 0.1142 - val_loss: 0.1980 - 2s/epoch - 13ms/step
# Epoch 9/50
# 124/124 - 2s - loss: 0.1158 - val_loss: 0.2034 - 2s/epoch - 13ms/step
# Epoch 10/50
# 124/124 - 2s - loss: 0.1150 - val_loss: 0.1835 - 2s/epoch - 13ms/step
# Epoch 11/50
# 124/124 - 2s - loss: 0.1132 - val_loss: 0.1798 - 2s/epoch - 13ms/step
# Epoch 12/50
# 124/124 - 2s - loss: 0.1128 - val_loss: 0.1605 - 2s/epoch - 13ms/step
# Epoch 13/50
# 124/124 - 2s - loss: 0.1121 - val_loss: 0.1849 - 2s/epoch - 13ms/step
# Epoch 14/50
# 124/124 - 2s - loss: 0.1126 - val_loss: 0.1716 - 2s/epoch - 13ms/step
# Epoch 15/50
# 124/124 - 2s - loss: 0.1122 - val_loss: 0.1919 - 2s/epoch - 13ms/step
# Epoch 16/50
# 124/124 - 2s - loss: 0.1126 - val_loss: 0.1993 - 2s/epoch - 13ms/step
# Epoch 17/50
# 124/124 - 2s - loss: 0.1102 - val_loss: 0.1755 - 2s/epoch - 13ms/step
# Epoch 18/50
# 124/124 - 2s - loss: 0.1095 - val_loss: 0.1687 - 2s/epoch - 13ms/step
# Epoch 19/50
# 124/124 - 2s - loss: 0.1101 - val_loss: 0.1720 - 2s/epoch - 13ms/step
# Epoch 20/50
# 124/124 - 2s - loss: 0.1093 - val_loss: 0.1625 - 2s/epoch - 13ms/step
# Epoch 21/50
# 124/124 - 2s - loss: 0.1088 - val_loss: 0.1454 - 2s/epoch - 13ms/step
# Epoch 22/50
# 124/124 - 2s - loss: 0.1085 - val_loss: 0.1602 - 2s/epoch - 13ms/step
# Epoch 23/50
# 124/124 - 2s - loss: 0.1086 - val_loss: 0.1728 - 2s/epoch - 13ms/step
# Epoch 24/50
# 124/124 - 2s - loss: 0.1092 - val_loss: 0.1535 - 2s/epoch - 13ms/step
# Epoch 25/50
# 124/124 - 2s - loss: 0.1074 - val_loss: 0.1754 - 2s/epoch - 13ms/step
# Epoch 26/50
# 124/124 - 2s - loss: 0.1081 - val_loss: 0.1697 - 2s/epoch - 13ms/step
# Epoch 27/50
# 124/124 - 2s - loss: 0.1068 - val_loss: 0.1595 - 2s/epoch - 13ms/step
# Epoch 28/50
# 124/124 - 2s - loss: 0.1071 - val_loss: 0.1592 - 2s/epoch - 13ms/step
# Epoch 29/50
# 124/124 - 2s - loss: 0.1071 - val_loss: 0.1570 - 2s/epoch - 13ms/step
# Epoch 30/50
# 124/124 - 2s - loss: 0.1064 - val_loss: 0.1451 - 2s/epoch - 13ms/step
# Epoch 31/50
# 124/124 - 2s - loss: 0.1060 - val_loss: 0.1554 - 2s/epoch - 13ms/step
# Epoch 32/50
# 124/124 - 2s - loss: 0.1064 - val_loss: 0.1468 - 2s/epoch - 13ms/step
# Epoch 33/50
# 124/124 - 2s - loss: 0.1058 - val_loss: 0.1539 - 2s/epoch - 13ms/step
# Epoch 34/50
# 124/124 - 2s - loss: 0.1062 - val_loss: 0.1642 - 2s/epoch - 13ms/step
# Epoch 35/50
# 124/124 - 2s - loss: 0.1048 - val_loss: 0.1531 - 2s/epoch - 13ms/step
# Epoch 36/50
# 124/124 - 2s - loss: 0.1057 - val_loss: 0.1520 - 2s/epoch - 13ms/step
# Epoch 37/50
# 124/124 - 2s - loss: 0.1049 - val_loss: 0.1497 - 2s/epoch - 13ms/step
# Epoch 38/50
# 124/124 - 2s - loss: 0.1047 - val_loss: 0.1491 - 2s/epoch - 13ms/step
# Epoch 39/50
# 124/124 - 2s - loss: 0.1045 - val_loss: 0.1478 - 2s/epoch - 13ms/step
# Epoch 40/50
# 124/124 - 2s - loss: 0.1053 - val_loss: 0.1550 - 2s/epoch - 13ms/step
# Epoch 41/50
# 124/124 - 2s - loss: 0.1048 - val_loss: 0.1635 - 2s/epoch - 13ms/step
# Epoch 42/50
# 124/124 - 2s - loss: 0.1054 - val_loss: 0.1531 - 2s/epoch - 13ms/step
# Epoch 43/50
# 124/124 - 2s - loss: 0.1044 - val_loss: 0.1453 - 2s/epoch - 13ms/step
# Epoch 44/50
# 124/124 - 2s - loss: 0.1033 - val_loss: 0.1531 - 2s/epoch - 13ms/step
# Epoch 45/50
# 124/124 - 2s - loss: 0.1044 - val_loss: 0.1566 - 2s/epoch - 13ms/step
# Epoch 46/50
# 124/124 - 2s - loss: 0.1034 - val_loss: 0.1505 - 2s/epoch - 13ms/step
# Epoch 47/50
# 124/124 - 2s - loss: 0.1044 - val_loss: 0.1474 - 2s/epoch - 13ms/step
# Epoch 48/50
# 124/124 - 2s - loss: 0.1037 - val_loss: 0.1571 - 2s/epoch - 13ms/step
# Epoch 49/50
# 124/124 - 2s - loss: 0.1039 - val_loss: 0.1481 - 2s/epoch - 13ms/step
# Epoch 50/50
# 124/124 - 2s - loss: 0.1041 - val_loss: 0.1537 - 2s/epoch - 13ms/step
# 124/124 [==============================] - 2s 4ms/step
# 31/31 [==============================] - 0s 4ms/step

# %%
history_dict2
# Out:
# {(0.0,
#   5,
#   8): {'loss': [0.15475773811340332,
#    0.13253238797187805,
#    0.1303892433643341,
#    0.12717211246490479,
#    0.12341667711734772,
#    0.12048135697841644,
#    0.11834326386451721,
#    0.11666835099458694,
#    0.11537947505712509,
#    0.11441388726234436,
#    0.11354425549507141,
#    0.11313782632350922,
#    0.11241823434829712,
#    0.11170222610235214,
#    0.11109105497598648,
#    0.11095384508371353,
#    0.11038614809513092,
#    0.11014357209205627,
#    0.10985337942838669,
#    0.10953936725854874,
#    0.10932612419128418,
#    0.10897849500179291,
#    0.10909058898687363,
#    0.10889622569084167,
#    0.10845854133367538,
#    0.10746711492538452,
#    0.10718818753957748,
#    0.10688643157482147,
#    0.10667180269956589,
#    0.10636162757873535,
#    0.10607380419969559,
#    0.10587365180253983,
#    0.10567887127399445,
#    0.10531841218471527,
#    0.10516022145748138,
#    0.1050054132938385,
#    0.10476183146238327,
#    0.10468433797359467,
#    0.10431218147277832,
#    0.10418210923671722,
#    0.10393591225147247,
#    0.10388466715812683,
#    0.10361970961093903,
#    0.10332977771759033,
#    0.10330918431282043,
#    0.1032518818974495,
#    0.10323774814605713,
#    0.10296228528022766,
#  (0.2, 5, 32): (0.13626328, 0.20262708),
#  (0.2, 10, 8): (0.13836746, 0.21325468),
#  (0.2, 10, 16): (0.13966495, 0.22732581),
#  (0.2, 10, 32): (0.13532731, 0.2189452),
#  (0.2, 25, 8): (0.1378877, 0.19590256),
#  (0.2, 25, 16): (0.1335329, 0.19223793),
#  (0.2, 25, 32): (0.13540038, 0.19643782),
#  (0.2, 50, 8): (0.134896, 0.19753304),
#  (0.2, 50, 16): (0.13289285, 0.17712364),
#  (0.2, 50, 32): (0.13610353, 0.17608248),
#  (0.4, 5, 8): (0.13637425, 0.18100026),
#  (0.4, 5, 16): (0.14096588, 0.19866827),
#  (0.4, 5, 32): (0.1374255, 0.21765411),
#  (0.4, 10, 8): (0.13662258, 0.19937237),
#  (0.4, 10, 16): (0.13892329, 0.21947311),
#  (0.4, 10, 32): (0.13920829, 0.20387286),
#  (0.4, 25, 8): (0.1343772, 0.17309771),
#  (0.4, 25, 16): (0.14127626, 0.20285352),
#  (0.4, 25, 32): (0.13506813, 0.19473179),
#  (0.4, 50, 8): (0.13403314, 0.18231592),
#  (0.4, 50, 16): (0.1311089, 0.17527026),
#  (0.4, 50, 32): (0.1308692, 0.18704014)}

# %%
val = 1
k1_train = ""
for key in scores2.keys():
    if scores2[key][0] < val:
        val = scores2[key][0]
        k1_train = key

print(k1_train)
# Out:
# (0.4, 50, 32)

# %%
lis_values = []
for v in scores2.values():
    lis_values.append(v[1])

# %%
lis_values
# Out:
# [0.17003718,
#  0.19760284,
#  0.18352616,
#  0.19384632,
#  0.18906502,
#  0.1755863,
#  0.20414266,
#  0.18048194,
#  0.17947766,
#  0.18913855,
#  0.19004434,
#  0.18055488,
#  0.22661376,
#  0.20552206,
#  0.20262708,
#  0.21325468,
#  0.22732581,
#  0.2189452,
#  0.19590256,
#  0.19223793,
#  0.19643782,
#  0.19753304,
#  0.17712364,
#  0.17608248,
#  0.18100026,
#  0.19866827,
#  0.21765411,
#  0.19937237,
#  0.21947311,
#  0.20387286,
#  0.17309771,
#  0.20285352,
#  0.19473179,
#  0.18231592,
#  0.17527026,
#  0.18704014]

# %%
lis_values.sort()

# %%
for l in lis_values[0:5]:
    print()
# Out:
# [0.17003718, 0.17309771, 0.17527026, 0.1755863, 0.17608248]

# %%
list_params = []
for v in scores2.keys():
    if scores2[v][1] in lis_values[0:5]:
        list_params.append(v)

# %%
colors = ["red", "blue", "turquoise", "purple", "pink"]
i = 0
for p in list_params:
  plt.plot(history_dict2[p]["loss"], c=colors[i], label=f"{p} val_loss: {'{0:.3f}'.format(scores2[p][1])}")
  plt.plot(history_dict2[p]["val_loss"], c=colors[i])
  plt.legend()
  i += 1
plt.xlabel("epochs")
plt.ylabel("loss")
plt.title("Loss and Validation Loss")
# Out:
# Text(0.5, 1.0, 'Loss and Validation Loss')

# %%
val = 1
k1_val = []

for key in scores2.keys():
    if scores2[key][1] < val:
        val = scores2[key][1]
        k1_val = key

print(k1_val)
# Out:
# (0.0, 5, 8)

# %%
val = 1
k2_train = ""
for key in history_dict2.keys():
    if history_dict2[key]["loss"][-1] < val:
        val = history_dict2[key]["loss"][-1]
        k2_train = key

print(k2_train)
# Out:
# (0.0, 50, 8)

# %%
for key in history_dict2.keys():
  plt.plot(history_dict2[key]["loss"])
  plt.plot(history_dict2[key]["val_loss"])

# %%
val = 1
k = ""
for key in history_dict2.keys():
    if history_dict2[key]["val_loss"][-1] < val:
        val = history_dict2[key]["val_loss"][-1]
        k = key

# %%
print(k)
# Out:
# (0.0, 5, 32)

# %%
plt.plot(history_dict2[k]["val_loss"])
plt.plot(history_dict2[k]["loss"])
plt.title(scores2[k])
# Out:
# Text(0.5, 1.0, '0.14007506')

# %%
val = 1
k2 = ""
for key in history_dict2.keys():
    if history_dict2[key]["loss"][-1] < val:
        val = history_dict2[key]["loss"][-1]
        k2 = key

# %%
print(k2)
# Out:
# (0.0, 25, 16)

# %%
plt.plot(history_dict2[k2]["val_loss"])
plt.plot(history_dict2[k2]["loss"])
plt.title(scores2[k2])
# Out:
# Text(0.5, 1.0, '0.1396037')

# %%
plt.plot(history_dict2[k3]["val_loss"])
plt.plot(history_dict2[k3]["loss"])
plt.title(scores2[k3])
# Out:
# Text(0.5, 1.0, '0.13166508')

# %% [markdown]
# ## Evaluate Model
# After the model is fit, we can forecast for the test dataset.
# Compute the error as the Root Mean Squared Error (RMSE).
#
# Compare the predictions and the real data

# %%
n_neurons = 5
dropout_rate=0
batch_size=8
finalmodel = Sequential()
 # train_X : 3D tensor (samples, lag_hours, feature)
 # single input_shape = (lag_days, feature)
finalmodel.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
finalmodel.add(Dropout(dropout_rate))
finalmodel.add(LSTM(n_neurons, return_sequences=True))
finalmodel.add(Dropout(dropout_rate))
finalmodel.add(LSTM(n_neurons, return_sequences=True))
finalmodel.add(Dropout(dropout_rate))
finalmodel.add(LSTM(n_neurons, return_sequences=True))
finalmodel.add(Dropout(dropout_rate))
finalmodel.add(LSTM(n_neurons))
finalmodel.add(Dense(1))  # 1 neuron in the output layer
finalmodel.compile(loss='mae', optimizer='adam')

finalmodel.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 493/493 - 15s - loss: 0.1438 - val_loss: 0.3648 - 15s/epoch - 30ms/step
# Epoch 2/50
# 493/493 - 4s - loss: 0.1334 - val_loss: 0.2765 - 4s/epoch - 8ms/step
# Epoch 3/50
# 493/493 - 4s - loss: 0.1185 - val_loss: 0.2030 - 4s/epoch - 8ms/step
# Epoch 4/50
# 493/493 - 4s - loss: 0.1146 - val_loss: 0.1947 - 4s/epoch - 8ms/step
# Epoch 5/50
# 493/493 - 4s - loss: 0.1129 - val_loss: 0.2028 - 4s/epoch - 8ms/step
# Epoch 6/50
# 493/493 - 4s - loss: 0.1121 - val_loss: 0.1949 - 4s/epoch - 8ms/step
# Epoch 7/50
# 493/493 - 4s - loss: 0.1114 - val_loss: 0.2036 - 4s/epoch - 8ms/step
# Epoch 8/50
# 493/493 - 4s - loss: 0.1108 - val_loss: 0.1999 - 4s/epoch - 8ms/step
# Epoch 9/50
# 493/493 - 4s - loss: 0.1102 - val_loss: 0.1888 - 4s/epoch - 8ms/step
# Epoch 10/50
# 493/493 - 4s - loss: 0.1095 - val_loss: 0.1847 - 4s/epoch - 8ms/step
# Epoch 11/50
# 493/493 - 4s - loss: 0.1090 - val_loss: 0.1817 - 4s/epoch - 8ms/step
# Epoch 12/50
# 493/493 - 4s - loss: 0.1084 - val_loss: 0.1832 - 4s/epoch - 8ms/step
# Epoch 13/50
# 493/493 - 4s - loss: 0.1078 - val_loss: 0.1811 - 4s/epoch - 8ms/step
# Epoch 14/50
# 493/493 - 4s - loss: 0.1077 - val_loss: 0.1756 - 4s/epoch - 8ms/step
# Epoch 15/50
# 493/493 - 4s - loss: 0.1071 - val_loss: 0.1792 - 4s/epoch - 8ms/step
# Epoch 16/50
# 493/493 - 4s - loss: 0.1071 - val_loss: 0.1753 - 4s/epoch - 8ms/step
# Epoch 17/50
# 493/493 - 4s - loss: 0.1067 - val_loss: 0.1727 - 4s/epoch - 8ms/step
# Epoch 18/50
# 493/493 - 4s - loss: 0.1066 - val_loss: 0.1717 - 4s/epoch - 7ms/step
# Epoch 19/50
# 493/493 - 4s - loss: 0.1062 - val_loss: 0.1661 - 4s/epoch - 7ms/step
# Epoch 20/50
# 493/493 - 4s - loss: 0.1059 - val_loss: 0.1659 - 4s/epoch - 7ms/step
# Epoch 21/50
# 493/493 - 4s - loss: 0.1058 - val_loss: 0.1614 - 4s/epoch - 7ms/step
# Epoch 22/50
# 493/493 - 4s - loss: 0.1056 - val_loss: 0.1608 - 4s/epoch - 7ms/step
# Epoch 23/50
# 493/493 - 4s - loss: 0.1053 - val_loss: 0.1534 - 4s/epoch - 7ms/step
# Epoch 24/50
# 493/493 - 4s - loss: 0.1053 - val_loss: 0.1571 - 4s/epoch - 7ms/step
# Epoch 25/50
# 493/493 - 4s - loss: 0.1052 - val_loss: 0.1590 - 4s/epoch - 7ms/step
# Epoch 26/50
# 493/493 - 4s - loss: 0.1050 - val_loss: 0.1580 - 4s/epoch - 7ms/step
# Epoch 27/50
# 493/493 - 4s - loss: 0.1049 - val_loss: 0.1544 - 4s/epoch - 7ms/step
# Epoch 28/50
# 493/493 - 4s - loss: 0.1049 - val_loss: 0.1552 - 4s/epoch - 7ms/step
# Epoch 29/50
# 493/493 - 4s - loss: 0.1047 - val_loss: 0.1528 - 4s/epoch - 7ms/step
# Epoch 30/50
# 493/493 - 4s - loss: 0.1046 - val_loss: 0.1560 - 4s/epoch - 7ms/step
# Epoch 31/50
# 493/493 - 4s - loss: 0.1044 - val_loss: 0.1552 - 4s/epoch - 7ms/step
# Epoch 32/50
# 493/493 - 4s - loss: 0.1042 - val_loss: 0.1554 - 4s/epoch - 7ms/step
# Epoch 33/50
# 493/493 - 4s - loss: 0.1042 - val_loss: 0.1529 - 4s/epoch - 7ms/step
# Epoch 34/50
# 493/493 - 4s - loss: 0.1040 - val_loss: 0.1529 - 4s/epoch - 7ms/step
# Epoch 35/50
# 493/493 - 4s - loss: 0.1039 - val_loss: 0.1513 - 4s/epoch - 7ms/step
# Epoch 36/50
# 493/493 - 4s - loss: 0.1039 - val_loss: 0.1515 - 4s/epoch - 8ms/step
# Epoch 37/50
# 493/493 - 4s - loss: 0.1039 - val_loss: 0.1512 - 4s/epoch - 7ms/step
# Epoch 38/50
# 493/493 - 4s - loss: 0.1037 - val_loss: 0.1497 - 4s/epoch - 7ms/step
# Epoch 39/50
# 493/493 - 4s - loss: 0.1036 - val_loss: 0.1536 - 4s/epoch - 7ms/step
# Epoch 40/50
# 493/493 - 4s - loss: 0.1036 - val_loss: 0.1482 - 4s/epoch - 7ms/step
# Epoch 41/50
# 493/493 - 4s - loss: 0.1037 - val_loss: 0.1491 - 4s/epoch - 7ms/step
# Epoch 42/50
# 493/493 - 4s - loss: 0.1035 - val_loss: 0.1498 - 4s/epoch - 7ms/step
# Epoch 43/50
# 493/493 - 4s - loss: 0.1034 - val_loss: 0.1472 - 4s/epoch - 7ms/step
# Epoch 44/50
# 493/493 - 4s - loss: 0.1034 - val_loss: 0.1495 - 4s/epoch - 7ms/step
# Epoch 45/50
# 493/493 - 4s - loss: 0.1033 - val_loss: 0.1463 - 4s/epoch - 7ms/step
# Epoch 46/50
# 493/493 - 4s - loss: 0.1031 - val_loss: 0.1481 - 4s/epoch - 7ms/step
# Epoch 47/50
# 493/493 - 4s - loss: 0.1031 - val_loss: 0.1469 - 4s/epoch - 7ms/step
# Epoch 48/50
# 493/493 - 4s - loss: 0.1030 - val_loss: 0.1474 - 4s/epoch - 7ms/step
# Epoch 49/50
# 493/493 - 4s - loss: 0.1027 - val_loss: 0.1474 - 4s/epoch - 7ms/step
# Epoch 50/50
# 493/493 - 4s - loss: 0.1030 - val_loss: 0.1453 - 4s/epoch - 7ms/step

# %%
ytest = test_y.reshape(test_y.shape[0], 1)

# %%
yhat = finalmodel.predict(test_X) 

# calculate RMSE
rmse = np.sqrt(mean_squared_error(test_y, yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# 52/52 [==============================] - 3s 3ms/step
# Test RMSE: 0.176

# %%
plt.plot(test_y, color='red', label='real data')

plt.plot(yhat, color='blue', label='predictions')
plt.legend()

# %%
n_neurons = 5
dropout_rate=0
batch_size=8
finalmodel2 = Sequential()
 # train_X : 3D tensor (samples, lag_hours, feature)
 # single input_shape = (lag_days, feature)
finalmodel2.add(LSTM(n_neurons, input_shape=(n_days, n_features), return_sequences=True))
finalmodel2.add(Dropout(dropout_rate))
finalmodel2.add(LSTM(n_neurons, return_sequences=True))
finalmodel2.add(Dropout(dropout_rate))
finalmodel2.add(LSTM(n_neurons, return_sequences=True))
finalmodel2.add(Dropout(dropout_rate))
finalmodel2.add(LSTM(n_neurons, return_sequences=True))
finalmodel2.add(Dropout(dropout_rate))
finalmodel2.add(LSTM(n_neurons, return_sequences=True))
finalmodel2.add(Dropout(dropout_rate))
finalmodel2.add(LSTM(n_neurons, return_sequences=True))
finalmodel2.add(Dropout(dropout_rate))
finalmodel2.add(LSTM(n_neurons, return_sequences=True))
finalmodel2.add(Dropout(dropout_rate))
finalmodel2.add(LSTM(n_neurons))
finalmodel2.add(Dense(1))  # 1 neuron in the output layer
finalmodel2.compile(loss='mae', optimizer='adam')

finalmodel2.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, validation_data=(val_X, val_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 493/493 - 24s - loss: 0.1428 - val_loss: 0.3643 - 24s/epoch - 49ms/step
# Epoch 2/50
# 493/493 - 6s - loss: 0.1248 - val_loss: 0.2297 - 6s/epoch - 12ms/step
# Epoch 3/50
# 493/493 - 6s - loss: 0.1142 - val_loss: 0.2539 - 6s/epoch - 12ms/step
# Epoch 4/50
# 493/493 - 6s - loss: 0.1124 - val_loss: 0.2486 - 6s/epoch - 11ms/step
# Epoch 5/50
# 493/493 - 6s - loss: 0.1113 - val_loss: 0.2456 - 6s/epoch - 11ms/step
# Epoch 6/50
# 493/493 - 5s - loss: 0.1103 - val_loss: 0.2389 - 5s/epoch - 11ms/step
# Epoch 7/50
# 493/493 - 6s - loss: 0.1099 - val_loss: 0.2313 - 6s/epoch - 11ms/step
# Epoch 8/50
# 493/493 - 6s - loss: 0.1095 - val_loss: 0.2257 - 6s/epoch - 11ms/step
# Epoch 9/50
# 493/493 - 5s - loss: 0.1090 - val_loss: 0.2204 - 5s/epoch - 11ms/step
# Epoch 10/50
# 493/493 - 6s - loss: 0.1083 - val_loss: 0.2132 - 6s/epoch - 11ms/step
# Epoch 11/50
# 493/493 - 6s - loss: 0.1077 - val_loss: 0.2169 - 6s/epoch - 11ms/step
# Epoch 12/50
# 493/493 - 6s - loss: 0.1075 - val_loss: 0.2036 - 6s/epoch - 11ms/step
# Epoch 13/50
# 493/493 - 6s - loss: 0.1069 - val_loss: 0.2032 - 6s/epoch - 11ms/step
# Epoch 14/50
# 493/493 - 6s - loss: 0.1068 - val_loss: 0.2011 - 6s/epoch - 13ms/step
# Epoch 15/50
# 493/493 - 6s - loss: 0.1058 - val_loss: 0.2048 - 6s/epoch - 11ms/step
# Epoch 16/50
# 493/493 - 6s - loss: 0.1056 - val_loss: 0.1903 - 6s/epoch - 11ms/step
# Epoch 17/50
# 493/493 - 6s - loss: 0.1053 - val_loss: 0.1795 - 6s/epoch - 11ms/step
# Epoch 18/50
# 493/493 - 6s - loss: 0.1051 - val_loss: 0.1788 - 6s/epoch - 12ms/step
# Epoch 19/50
# 493/493 - 6s - loss: 0.1048 - val_loss: 0.1798 - 6s/epoch - 11ms/step
# Epoch 20/50
# 493/493 - 6s - loss: 0.1047 - val_loss: 0.1765 - 6s/epoch - 11ms/step
# Epoch 21/50
# 493/493 - 6s - loss: 0.1047 - val_loss: 0.1724 - 6s/epoch - 12ms/step
# Epoch 22/50
# 493/493 - 6s - loss: 0.1046 - val_loss: 0.1709 - 6s/epoch - 11ms/step
# Epoch 23/50
# 493/493 - 6s - loss: 0.1046 - val_loss: 0.1680 - 6s/epoch - 11ms/step
# Epoch 24/50
# 493/493 - 6s - loss: 0.1045 - val_loss: 0.1674 - 6s/epoch - 11ms/step
# Epoch 25/50
# 493/493 - 6s - loss: 0.1042 - val_loss: 0.1668 - 6s/epoch - 11ms/step
# Epoch 26/50
# 493/493 - 6s - loss: 0.1041 - val_loss: 0.1664 - 6s/epoch - 11ms/step
# Epoch 27/50
# 493/493 - 6s - loss: 0.1041 - val_loss: 0.1660 - 6s/epoch - 11ms/step
# Epoch 28/50
# 493/493 - 5s - loss: 0.1041 - val_loss: 0.1631 - 5s/epoch - 11ms/step
# Epoch 29/50
# 493/493 - 6s - loss: 0.1040 - val_loss: 0.1611 - 6s/epoch - 12ms/step
# Epoch 30/50
# 493/493 - 6s - loss: 0.1038 - val_loss: 0.1606 - 6s/epoch - 11ms/step
# Epoch 31/50
# 493/493 - 6s - loss: 0.1039 - val_loss: 0.1619 - 6s/epoch - 11ms/step
# Epoch 32/50
# 493/493 - 6s - loss: 0.1039 - val_loss: 0.1598 - 6s/epoch - 12ms/step
# Epoch 33/50
# 493/493 - 6s - loss: 0.1039 - val_loss: 0.1597 - 6s/epoch - 11ms/step
# Epoch 34/50
# 493/493 - 6s - loss: 0.1038 - val_loss: 0.1602 - 6s/epoch - 11ms/step
# Epoch 35/50
# 493/493 - 6s - loss: 0.1038 - val_loss: 0.1613 - 6s/epoch - 11ms/step
# Epoch 36/50
# 493/493 - 6s - loss: 0.1037 - val_loss: 0.1580 - 6s/epoch - 11ms/step
# Epoch 37/50
# 493/493 - 6s - loss: 0.1035 - val_loss: 0.1595 - 6s/epoch - 12ms/step
# Epoch 38/50
# 493/493 - 6s - loss: 0.1036 - val_loss: 0.1560 - 6s/epoch - 12ms/step
# Epoch 39/50
# 493/493 - 6s - loss: 0.1034 - val_loss: 0.1589 - 6s/epoch - 11ms/step
# Epoch 40/50
# 493/493 - 6s - loss: 0.1032 - val_loss: 0.1571 - 6s/epoch - 12ms/step
# Epoch 41/50
# 493/493 - 6s - loss: 0.1031 - val_loss: 0.1552 - 6s/epoch - 11ms/step
# Epoch 42/50
# 493/493 - 6s - loss: 0.1031 - val_loss: 0.1555 - 6s/epoch - 11ms/step
# Epoch 43/50
# 493/493 - 6s - loss: 0.1027 - val_loss: 0.1535 - 6s/epoch - 11ms/step
# Epoch 44/50
# 493/493 - 6s - loss: 0.1027 - val_loss: 0.1539 - 6s/epoch - 11ms/step
# Epoch 45/50
# 493/493 - 6s - loss: 0.1025 - val_loss: 0.1542 - 6s/epoch - 11ms/step
# Epoch 46/50
# 493/493 - 6s - loss: 0.1023 - val_loss: 0.1549 - 6s/epoch - 12ms/step
# Epoch 47/50
# 493/493 - 5s - loss: 0.1022 - val_loss: 0.1585 - 5s/epoch - 11ms/step
# Epoch 48/50
# 493/493 - 6s - loss: 0.1021 - val_loss: 0.1562 - 6s/epoch - 12ms/step
# Epoch 49/50
# 493/493 - 6s - loss: 0.1020 - val_loss: 0.1539 - 6s/epoch - 11ms/step
# Epoch 50/50
# 493/493 - 5s - loss: 0.1017 - val_loss: 0.1531 - 5s/epoch - 11ms/step

# %%
yhat = finalmodel2.predict(test_X) 

# calculate RMSE
rmse = np.sqrt(mean_squared_error(test_y, yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# 52/52 [==============================] - 4s 5ms/step
# Test RMSE: 0.181

# %%
plt.plot(test_y, color='red', label='real data')

plt.plot(yhat, color='blue', label='predictions')
plt.legend()
